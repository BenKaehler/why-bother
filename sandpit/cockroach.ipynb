# %%
from itertools import combinations
from collections import Counter, defaultdict

from cogent3 import load_aligned_seqs, PhyloNode
import numpy as np
from sklearn.cluster import SpectralClustering
import networkx as nx

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors
tfl = tf.linalg

tf.executing_eagerly()  # need to check whether this is the default for tensorflow > 2
# Out:
# 2021-11-22 12:14:29.408670: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# True

# %%
# this stops tensorflow from snaffling all of the GPU
# thanks https://stackoverflow.com/questions/34199233/how-to-prevent-tensorflow-from-allocating-the-totality-of-a-gpu-memory
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2021-11-22 12:14:30.835811: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-11-22 12:14:30.905203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-22 12:14:30.905544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 with Max-Q Design computeCapability: 7.5
# coreClock: 1.095GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 357.69GiB/s
# 2021-11-22 12:14:30.905570: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-22 12:14:30.921009: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-11-22 12:14:30.931978: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-11-22 12:14:30.935708: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-11-22 12:14:30.956563: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-11-22 12:14:30.961107: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-11-22 12:14:31.011681: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-11-22 12:14:31.012109: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-22 12:14:31.013516: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-22 12:14:31.014628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0

# %%
def get_triples(aln, nuc_order='ACGT', codon_position=None, verbose=False):
    if codon_position:
        aln = aln[codon_position - 1::3]
    aln = aln.no_degenerates()
    if verbose:
        print(f'Got {len(aln)} positions')
    assert len(aln) <= np.iinfo(np.int32).max
    triples = []
    nuc_map = {n:i for i, n in enumerate(nuc_order)}
    for triple in combinations(range(aln.num_seqs), 3):
        F = np.zeros([4, 4, 4], dtype=np.int32)
        subaln = aln.get_sub_alignment(seqs=triple)
        for a, b, c in subaln:
            F[nuc_map[a], nuc_map[b], nuc_map[c]] += 1
        triples.append([tuple(subaln.names), F])
    return triples

# %%
@tf.function()
def transform_P_matrix(Q, t):
    Q0 = tf.concat([[-tf.reduce_sum(Q[0])], Q[0]], axis=0)
    Q1 = tf.concat([[Q[1,0]], [-tf.reduce_sum(Q[1])], Q[1,1:]],
                   axis=0)
    Q = tf.concat([[Q0], [Q1], [Q1[::-1]], [Q0[::-1]]], axis=0)
    return tf.linalg.expm(Q*t)

@tf.function()
def compose_P(pi, Q, ti, to):
    Pi = transform_P_matrix(Q, ti)
    Piinv = transform_P_matrix(Q, -ti)
    Po = transform_P_matrix(Q, to)
    P = tfl.matmul(tfl.diag(1/pi), Pi, transpose_b=True)
    P = tfl.matmul(P, tfl.diag(tf.matmul(tf.reshape(pi, shape=(1,4)), Piinv)))
    P = tfl.matmul(P, Po)[0]
    return P

@tf.function()
def transform(params):
    ptis = tf.exp(params[:3]) / (1 + tf.exp(params[:3]))
    pi = tfb.SoftmaxCentered()(params[3:6])
    ts = tf.exp(params[6:9])
    tab, tbc, tac = [ts[i] for i in range(3)]
    max0 = tfb.SoftClip(low=0, hinge_softness=0.05)  # 0.05)  # 0.01)
    toa = max0((tab + tac - tbc) / 2)
    tob = max0((tab + tbc - tac) / 2)
    toc = max0((tbc + tac - tab) / 2)
    tia = ptis[0] * toa
    tib = ptis[1] * tob
    tic = ptis[2] * toc
    
    Q_raw = params[9:]
    #Q = tfb.SoftmaxCentered()(Q_raw)
    Q = tf.concat([[Q_raw[1]], Q_raw, [Q_raw[1]], [Q_raw[1]]], axis=0)
    Q = tfb.SoftmaxCentered()(Q)
    Q = tf.stack([Q[:3], Q[3:]])
    Pa = compose_P(pi, Q, tia, toa)
    Pb = compose_P(pi, Q, tib, tob)
    Pc = compose_P(pi, Q, tic, toc)
    return pi, Pa, Pb, Pc, tia, tib, tic, toa, tob, toc, Q

@tf.function()
def _loss(params_data):
    params, data = params_data
    pi, Pa, Pb, Pc, tia, tib, tic, _, _, _, _ = transform(params)
    J = tf.einsum('i,ij,ik,il', pi, Pa, Pb, Pc)
    loss = tf.reduce_sum(tf.keras.losses.KLDivergence()(J, data)) # + \
#        0.01 * (tia + tib + tic)
#        0.01 * tf.reduce_sum(tf.exp(params[:6]))
#        0.01 * (tf.reduce_sum(tf.exp(params[:3])) - 0.99 * tf.reduce_max(tf.exp(params[:3])))
    return loss
    
@tf.function()
def loss(params, data):
    return tf.reduce_sum(tf.vectorized_map(_loss, (params, data)))

@tf.function()
def stack_params(Qs, pis_and_tis, ts, sharesies, tix):
    parameters = [tf.concat([pis_and_tis[j],
                            [ts[tix[j,k]] for k in range(3)],
                            Qs[sharesies[j]]], axis=0)
                  for j in range(len(sharesies))]
    return tf.stack(parameters)

@tf.function()
def training_step(parameters, data, optimizer):
    Qs, pis_and_tis, ts, sharesies, tix = parameters
    with tf.GradientTape() as tape:
        params = stack_params(Qs, pis_and_tis, ts, sharesies, tix)
        loss_value = loss(params, data)
    gradients = tape.gradient(loss_value, parameters[:3])
    return loss_value, gradients

# thanks https://github.com/mlgxmez/thelongrun_notebooks/blob/master/MLE_tutorial.ipynb
def mle_fit(data, loss, parameters, optimizer, steps=500, verbose=False):
    for i in range(steps):
        loss_value, gradients = training_step(parameters, data, optimizer)
        optimizer.apply_gradients(zip(gradients, parameters[:3]))
        
        if i % 100 == 0:
            if verbose:
                iter_info = f"Step: {optimizer.iterations.numpy()}, initial loss: {loss_value.numpy()}"
                print(iter_info)

def fit_triples(triples, t_sharesies=None, Q_sharesies=None, learning_rate=0.01, steps=3000, verbose=False):
    if Q_sharesies is None:
        Q_sharesies = list(range(len(triples)))
    assert len(triples) == len(Q_sharesies), 'triples and Q_sharesies mismatch'
    unique_Q_sharesies = list(set(Q_sharesies))
    Q_sharesies = [unique_Q_sharesies.index(s) for s in Q_sharesies]
    
    if t_sharesies is None:
        t_sharesies = list(range(len(triples)))
    assert len(triples) == len(t_sharesies), 'triples and t_sharesies mismatch'
    
    normal_initializer = tf.random_normal_initializer()
    Qs = tf.Variable(normal_initializer(shape=(len(unique_Q_sharesies), 2),
                                        dtype=tf.float32))

    pis_and_tis = tf.Variable(normal_initializer(shape=(len(triples), 6),
                                                 dtype=tf.float32))
    
    pairs = defaultdict(set)
    for (triple, _), group in zip(triples, t_sharesies):
        pairs[group].update(frozenset((a, b)) for a in triple for b in triple if a != b)
    pairs = [(g, p) for g, pairset in pairs.items() for p in pairset]
    tix = []
    for (triple, _), group in zip(triples, t_sharesies):
        ix = []
        for i in (0, 1, 2):
            ix.append(pairs.index((group, frozenset((triple[i], triple[(i+1)%3])))))
        tix.append(ix)
    length_initializer = tf.random_normal_initializer(mean=-0.7, stddev=0.35)
    ts = tf.Variable(length_initializer(shape=(len(pairs),), dtype=tf.float32))
    tix = tf.constant(tix)
    
    Q_sharesies = tf.constant(Q_sharesies)
    
    parameters = [Qs, pis_and_tis, ts, Q_sharesies, tix]
    
    data = []
    for names, F in triples:
        data.append(F/F.sum())
    data = tf.constant(data, dtype=tf.float32)
    
    if verbose:
        print(f'Fitting {data.shape[0]} triple(s) using {Qs.shape[0]} '
              f'rate matrix(es) and {ts.shape[0]} tip-to-tip distance(s).')
    optimizer = tf.optimizers.Adam(learning_rate=learning_rate)
    mle_fit(data, loss, parameters, optimizer, steps=steps, verbose=verbose)
    
#     for a, (b, _) in zip(tix, triples):
#         print(a, b)
#     for i, p in enumerate(pairs):
#         print(np.exp(ts[i].numpy()), p)
    
    parameters = stack_params(Qs, pis_and_tis, ts, Q_sharesies, tix)
    output_parameters = [transform(parameters[i]) for i in range(len(parameters))]
    losses = tf.vectorized_map(_loss, (parameters, data)).numpy()
    return losses, output_parameters

# %%
def get_edges(triples, lengths, losses):
    edges = Counter()
    for lens, ls, (names, F) in zip(lengths, losses, triples):
        weights = lens/lens.sum()
        for name, weight in zip(names, weights):
            edges[frozenset(names) - {name}] += weight
    return edges

def edges_to_graph(edges):
    G = nx.Graph()
    for edge, weight in edges.items():
        G.add_edge(*edge, weight=weight)
    return G

def pulsar(triples, learning_rate=0.01, steps=3000, verbose=False):
    losses, params = fit_triples(triples, learning_rate=learning_rate,
                         steps=steps, verbose=verbose, sharesies=[0]*len(triples))
    lengths = [np.exp(p[:3]) for p in params]
    tree = pulsar_tree(triples, lengths, losses, verbose=verbose)
    return tree

def normalised_cut(edges, verbose=False):
    tips = np.unique([t for p in edges.keys() for t in p])
    affinity = np.zeros((len(tips),)*2)
    for i, tipi in enumerate(tips):
        for j, tipj in enumerate(tips):
            if i == j:
                break
            affinity[i, j] = edges[frozenset((tipi, tipj))]
    affinity += affinity.T
    sc = SpectralClustering(2, affinity='precomputed',  # random_state=0,
                            assign_labels='discretize')
    ix = sc.fit_predict(affinity).astype(bool)
    partition = list(tips[ix]), list(tips[np.logical_not(ix)])
    if verbose:
        G = edges_to_graph(edges)
        cut_value = nx.cut_size(G, partition[0], weight='weight')
        print(f'Cut value: {cut_value}, Partition:\n{partition}')
    return partition

def pulsar_tree(triples, lengths, losses, verbose=False):
    assert len(triples) == len(lengths)
    assert len(triples) == len(losses)
    
    edges = get_edges(triples, lengths, losses)
    if verbose:
        print('Graph:')
        for edge, weight in edges.items():
            print(edge, weight)
    partition = normalised_cut(edges, verbose)
    assert len(partition) == 2, 'polytomy detected. bailing'
    this_node = PhyloNode()
    for part in partition:
        if len(part) <= 1:
            this_node.append(PhyloNode(part.pop()))
            continue
        elif len(part) == 2:
            child = PhyloNode()
            for grandchild in part:
                child.append(PhyloNode(grandchild))
            this_node.append(child)
            continue
    
        part = set(part)
        part_losses = []
        part_triples = []
        part_lengths = []
        for lens, ls, (names, F) in zip(lengths, losses, triples):
            if set(names) <= part:
                part_lengths.append(lens)
                part_losses.append(ls)
                part_triples.append((names, F))
        this_node.append(pulsar_tree(part_triples, part_lengths, part_losses, verbose=verbose))
    return this_node

# %%
# %%time
aln = load_aligned_seqs('/home/ben/Data/pentads/ENSG00000131018.fa.gz', moltype="dna")
triples = get_triples(aln, codon_position=3, verbose=True)
losses, params = fit_triples(triples, verbose=True, steps=3000,
                             Q_sharesies=[0]*len(triples), t_sharesies = [0]*len(triples))
# Out:
# Got 1379 positions
# Fitting 10 triple(s) using 1 rate matrix(es) and 10 tip-to-tip distance(s).
# Step: 1, initial loss: 0.28244325518608093
# Step: 101, initial loss: 0.06167846918106079
# Step: 201, initial loss: 0.03899339959025383
# Step: 301, initial loss: 0.03469279780983925
# Step: 401, initial loss: 0.03297993168234825
# Step: 501, initial loss: 0.03209149092435837
# Step: 601, initial loss: 0.03158606216311455
# Step: 701, initial loss: 0.031270310282707214
# Step: 801, initial loss: 0.031056631356477737
# Step: 901, initial loss: 0.03090176172554493
# Step: 1001, initial loss: 0.03078506886959076
# Step: 1101, initial loss: 0.030695773661136627
# Step: 1201, initial loss: 0.030626222491264343
# Step: 1301, initial loss: 0.03057095594704151
# Step: 1401, initial loss: 0.030526183545589447
# Step: 1501, initial loss: 0.030489183962345123
# Step: 1601, initial loss: 0.030458297580480576
# Step: 1701, initial loss: 0.030432214960455894
# Step: 1801, initial loss: 0.030410021543502808
# Step: 1901, initial loss: 0.0303907822817564
# Step: 2001, initial loss: 0.030373994261026382
# Step: 2101, initial loss: 0.030359189957380295
# Step: 2201, initial loss: 0.03034607321023941
# Step: 2301, initial loss: 0.030334239825606346
# Step: 2401, initial loss: 0.0303235724568367
# Step: 2501, initial loss: 0.030313897877931595
# Step: 2601, initial loss: 0.03030516393482685
# Step: 2701, initial loss: 0.03029710426926613
# Step: 2801, initial loss: 0.03028983622789383
# Step: 2901, initial loss: 0.030283164232969284
# CPU times: user 3min 13s, sys: 21.7 s, total: 3min 34s
# Wall time: 1min 48s

# %%
losses
# Out:
# array([0.00247569, 0.00580734, 0.00419697, 0.00364184, 0.00372384,
#        0.00199067, 0.00160424, 0.00357931, 0.00287118, 0.00297137])

# %%
losses
# Out:
# array([0.00173156, 0.00489512, 0.00330998, 0.00374211, 0.00403919,
#        0.00181286, 0.00157304, 0.00399779, 0.00246676, 0.00270869],
#       dtype=float32)

# %%
list(zip((n for n, _ in triples), (np.exp(p[:3]) for p in params)))
# Out:
# [(('Dog', 'Human', 'Mouse'),
#   array([0.07298953, 0.10161132, 0.05906086], dtype=float32)),
#  (('Dog', 'Human', 'Opossum'),
#   array([0.09708241, 0.08377995, 0.6660794 ], dtype=float32)),
#  (('Dog', 'Human', 'Platypus'),
#   array([0.09662799, 0.05149724, 0.7859325 ], dtype=float32)),
#  (('Dog', 'Mouse', 'Opossum'),
#   array([0.09756454, 0.12715098, 0.5615496 ], dtype=float32)),
#  (('Dog', 'Mouse', 'Platypus'),
#   array([0.22691889, 0.07538477, 0.6418923 ], dtype=float32)),
#  (('Dog', 'Opossum', 'Platypus'),
#   array([0.3081079 , 0.39696702, 0.44309965], dtype=float32)),
#  (('Human', 'Mouse', 'Opossum'),
#   array([0.13214006, 0.07260554, 0.5675322 ], dtype=float32)),
#  (('Human', 'Mouse', 'Platypus'),
#   array([0.16070251, 0.08125931, 0.57675904], dtype=float32)),
#  (('Human', 'Opossum', 'Platypus'),
#   array([0.1439011 , 0.3845076 , 0.37645704], dtype=float32)),
#  (('Mouse', 'Opossum', 'Platypus'),
#   array([0.17595707, 0.3732416 , 0.38440546], dtype=float32))]

# %%
list(zip((n for n, _ in triples), losses, [np.array([p.numpy() for p in param[4:10]]) for param in params]))
# Out:
# [(('Dog', 'Human', 'Mouse'),
#   0.0017315601,
#   array([0.0609278 , 0.05544734, 0.12454414, 0.13344057, 0.16606377,
#          0.61740303], dtype=float32)),
#  (('Dog', 'Human', 'Opossum'),
#   0.0048951195,
#   array([0.00089988, 0.0055109 , 0.3468333 , 0.12890965, 0.17078088,
#          0.34949952], dtype=float32)),
#  (('Dog', 'Human', 'Platypus'),
#   0.0033099754,
#   array([0.05474074, 0.00290636, 0.4005302 , 0.14595523, 0.15327966,
#          0.40244585], dtype=float32)),
#  (('Dog', 'Mouse', 'Opossum'),
#   0.0037421086,
#   array([0.00113644, 0.05251506, 0.3040527 , 0.17119642, 0.57771105,
#          0.30498797], dtype=float32)),
#  (('Dog', 'Mouse', 'Platypus'),
#   0.0040391926,
#   array([0.05881398, 0.03780889, 0.38075227, 0.16513251, 0.5839924 ,
#          0.38237575], dtype=float32)),
#  (('Dog', 'Opossum', 'Platypus'),
#   0.001812863,
#   array([0.19560938, 0.16787796, 0.23364855, 0.30799335, 0.16828553,
#          0.23815155], dtype=float32)),
#  (('Human', 'Mouse', 'Opossum'),
#   0.0015730357,
#   array([0.02075593, 0.06622321, 0.30844897, 0.20956491, 0.5728256 ,
#          0.309863  ], dtype=float32)),
#  (('Human', 'Mouse', 'Platypus'),
#   0.0039977883,
#   array([0.0126724 , 0.06361055, 0.36678666, 0.18554112, 0.5973252 ,
#          0.36905023], dtype=float32)),
#  (('Human', 'Opossum', 'Platypus'),
#   0.0024667615,
#   array([0.16498642, 0.18502308, 0.20265345, 0.33388057, 0.18597363,
#          0.22012067], dtype=float32)),
#  (('Mouse', 'Opossum', 'Platypus'),
#   0.0027086923,
#   array([0.15111028, 0.16161488, 0.20422673, 0.72233963, 0.16223465,
#          0.24438265], dtype=float32))]

# %%
params
# Out:
# <tf.Tensor: shape=(10, 11), dtype=float32, numpy=
# array([[-2.708005  , -2.3047087 , -2.538702  , -2.4713752 , -1.947004  ,
#         -0.49924543,  0.05634893, -0.41402954,  0.08538109,  1.3506602 ,
#         -0.95855683],
#        [-4.7744646 , -4.5075455 , -1.6724694 , -1.4267347 , -1.2865919 ,
#         -0.57767147,  0.19750692, -1.0690533 , -5.043477  ,  1.3506602 ,
#         -0.95855683],
#        [-2.6475873 , -2.6633735 , -0.5653625 , -2.617783  , -2.0681472 ,
#         -0.968321  ,  0.1028522 , -0.3440413 ,  0.14183377,  1.3506602 ,
#         -0.95855683],
#        [-2.438525  , -2.336017  , -0.5599119 , -2.4999914 , -0.65879494,
#         -1.6509225 ,  0.06806601, -0.25119123,  0.20840725,  1.3506602 ,
#         -0.95855683],
#        [-1.444854  , -2.6757386 , -0.40964496, -3.0720534 , -0.7538406 ,
#         -1.6699716 ,  0.08764298, -0.11357285,  0.34374702,  1.3506602 ,
#         -0.95855683],
#        [-0.9719933 , -0.88674045, -0.7620446 , -1.2795044 , -3.358952  ,
#         -1.8986369 ,  0.10729649, -0.18676305,  0.2584809 ,  1.3506602 ,
#         -0.95855683],
#        [-1.9618127 , -2.3108    , -0.56780803, -2.1394744 , -0.6152218 ,
#         -1.5595605 ,  0.08581   , -0.23462065,  0.23512517,  1.3506602 ,
#         -0.95855683],
#        [-1.7595164 , -2.686603  , -0.4866251 , -2.4542215 , -0.6595694 ,
#         -1.603674  ,  0.11090785, -0.15318541,  0.31765392,  1.3506602 ,
#         -0.95855683],
#        [-1.3835816 , -1.130188  , -1.0575439 , -1.0120051 , -2.4151874 ,
#         -1.6295687 ,  0.12332566, -0.38600674,  0.13397779,  1.3506602 ,
#         -0.95855683],
#        [-1.5730361 , -0.8731208 , -0.84496164, -0.3352186 , -3.3998191 ,
#         -2.2593043 ,  0.11854389, -0.2091755 ,  0.2539441 ,  1.3506602 ,
#         -0.95855683]], dtype=float32)>

# %%
lengths = [np.array([p.numpy() for p in param[4:7]]) for param in params]
tree = pulsar_tree(triples, lengths, losses, verbose=True)
print(tree.ascii_art())
# Out:
# Graph:
# frozenset({'Mouse', 'Human'}) 1.8607659339904785
# frozenset({'Mouse', 'Dog'}) 1.8777560740709305
# frozenset({'Dog', 'Human'}) 2.3729870915412903
# frozenset({'Opossum', 'Human'}) 0.536705068545416
# frozenset({'Opossum', 'Dog'}) 0.5536943003535271
# frozenset({'Platypus', 'Human'}) 0.5978275388479233
# frozenset({'Platypus', 'Dog'}) 0.3666835343465209
# frozenset({'Mouse', 'Opossum'}) 0.4507262341212481
# frozenset({'Mouse', 'Platypus'}) 0.4644346237182617
# frozenset({'Opossum', 'Platypus'}) 0.9184193313121796
# Cut value: 2.970071299932897, Partition:
# (['Opossum', 'Platypus'], ['Dog', 'Human', 'Mouse'])
# Graph:
# frozenset({'Mouse', 'Human'}) 0.25289714336395264
# frozenset({'Mouse', 'Dog'}) 0.230149045586586
# frozenset({'Dog', 'Human'}) 0.5169537663459778
# Cut value: 0.48304618895053864, Partition:
# (['Mouse'], ['Dog', 'Human'])
#                     /-Opossum
#           /--------|
#          |          \-Platypus
# ---------|
#          |          /-Mouse
#           \--------|
#                    |          /-Dog
#                     \--------|
#                               \-Human

# %%
# %%time
aln = load_aligned_seqs('brca1.fasta', moltype='dna')
subaln = aln.get_similar(aln.take_seqs(['Human']).seqs[0], min_similarity=0.84)
triples = get_triples(subaln, codon_position=3, verbose=True)
tree = pulsar(triples, verbose=True)
print(tree.ascii_art())
# Out:
# Got 881 positions
# Fitting 455 triples using 1 rate matrix(es)
# Step: 1, initial loss: 148.9008026123047
# Step: 101, initial loss: 40.13922882080078
# Step: 201, initial loss: 23.3443603515625
# Step: 301, initial loss: 19.115922927856445
# Step: 401, initial loss: 16.462268829345703
# Step: 501, initial loss: 14.36288833618164
# Step: 601, initial loss: 12.7217378616333
# Step: 701, initial loss: 11.5491304397583
# Step: 801, initial loss: 10.769973754882812
# Step: 901, initial loss: 10.237008094787598
# Step: 1001, initial loss: 9.82467269897461
# Step: 1101, initial loss: 9.46207046508789
# Step: 1201, initial loss: 9.078824996948242
# Step: 1301, initial loss: 8.74043083190918
# Step: 1401, initial loss: 8.47661304473877
# Step: 1501, initial loss: 8.271474838256836
# Step: 1601, initial loss: 8.111785888671875
# Step: 1701, initial loss: 7.9773149490356445
# Step: 1801, initial loss: 7.854578495025635
# Step: 1901, initial loss: 7.747161865234375
# Step: 2001, initial loss: 7.646888256072998
# Step: 2101, initial loss: 7.560892581939697
# Step: 2201, initial loss: 7.4938459396362305
# Step: 2301, initial loss: 7.440583229064941
# Step: 2401, initial loss: 7.401652812957764
# Step: 2501, initial loss: 7.3694634437561035
# Step: 2601, initial loss: 7.34324836730957
# Step: 2701, initial loss: 7.318523406982422
# Step: 2801, initial loss: 7.293198108673096
# Step: 2901, initial loss: 7.274057865142822
# WARNING:tensorflow:11 out of the last 11 calls to <function pfor.<locals>.f at 0x7f82f9dd9e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Graph:
# frozenset({'Rhino', 'Pangolin'}) 0.202620979398489
# frozenset({'Pangolin', 'Horse'}) 0.14177491702139378
# frozenset({'Rhino', 'Horse'}) 0.2508750632405281
# frozenset({'Rhino', 'Llama'}) 0.2745061367750168
# frozenset({'Horse', 'Llama'}) 0.1684773052111268
# frozenset({'Rhino', 'SpermWhale'}) 0.3254824411123991
# frozenset({'Horse', 'SpermWhale'}) 0.24759249342605472
# frozenset({'Rhino', 'HumpbackW'}) 0.32551642786711454
# frozenset({'Horse', 'HumpbackW'}) 0.24157964251935482
# frozenset({'Rhino', 'FlyingLem'}) 0.25172886438667774
# frozenset({'Horse', 'FlyingLem'}) 0.2193962251767516
# frozenset({'Rhino', 'HowlerMon'}) 0.2753943055868149
# frozenset({'HowlerMon', 'Horse'}) 0.28962270449846983
# frozenset({'Rhino', 'Rhesus'}) 0.30443268176168203
# frozenset({'Horse', 'Rhesus'}) 0.376806135289371
# frozenset({'Rhino', 'Orangutan'}) 0.31383943371474743
# frozenset({'Horse', 'Orangutan'}) 0.3923333715647459
# frozenset({'Rhino', 'Gorilla'}) 0.3425984401255846
# frozenset({'Horse', 'Gorilla'}) 0.41901986859738827
# frozenset({'Rhino', 'Human'}) 0.2550982458051294
# frozenset({'Horse', 'Human'}) 0.2527689477428794
# frozenset({'Rhino', 'Chimpanzee'}) 0.40445677004754543
# frozenset({'Horse', 'Chimpanzee'}) 0.43868718575686216
# frozenset({'Rhino', 'HairyArma'}) 0.33411724492907524
# frozenset({'Horse', 'HairyArma'}) 0.24384822696447372
# frozenset({'Rhino', 'Sloth'}) 0.2699226774275303
# frozenset({'Sloth', 'Horse'}) 0.22001215163618326
# frozenset({'Pangolin', 'Llama'}) 0.2470740396529436
# frozenset({'Pangolin', 'SpermWhale'}) 0.3420217726379633
# frozenset({'Pangolin', 'HumpbackW'}) 0.32596668414771557
# frozenset({'Pangolin', 'FlyingLem'}) 0.1986942132934928
# frozenset({'Pangolin', 'HowlerMon'}) 0.23126928508281708
# frozenset({'Pangolin', 'Rhesus'}) 0.22210081946104765
# frozenset({'Pangolin', 'Orangutan'}) 0.419802013784647
# frozenset({'Pangolin', 'Gorilla'}) 0.46567905601114035
# frozenset({'Pangolin', 'Human'}) 0.49219317920506
# frozenset({'Pangolin', 'Chimpanzee'}) 0.4834749372676015
# frozenset({'Pangolin', 'HairyArma'}) 0.22596968058496714
# frozenset({'Pangolin', 'Sloth'}) 0.2288526827469468
# frozenset({'Llama', 'SpermWhale'}) 0.39140394795686007
# frozenset({'Llama', 'HumpbackW'}) 0.3338348576799035
# frozenset({'Llama', 'FlyingLem'}) 0.2282166313380003
# frozenset({'HowlerMon', 'Llama'}) 0.26169328670948744
# frozenset({'Llama', 'Rhesus'}) 0.22745884861797094
# frozenset({'Orangutan', 'Llama'}) 0.41456019319593906
# frozenset({'Llama', 'Gorilla'}) 0.4448686642572284
# frozenset({'Human', 'Llama'}) 0.4592271652072668
# frozenset({'Llama', 'Chimpanzee'}) 0.46870194748044014
# frozenset({'Llama', 'HairyArma'}) 0.3412911659106612
# frozenset({'Sloth', 'Llama'}) 0.27608349826186895
# frozenset({'HumpbackW', 'SpermWhale'}) 0.6313440203666687
# frozenset({'SpermWhale', 'FlyingLem'}) 0.3510741600766778
# frozenset({'HowlerMon', 'SpermWhale'}) 0.3562581529840827
# frozenset({'SpermWhale', 'Rhesus'}) 0.35964022297412157
# frozenset({'Orangutan', 'SpermWhale'}) 0.5035582082346082
# frozenset({'SpermWhale', 'Gorilla'}) 0.44345251750200987
# frozenset({'Human', 'SpermWhale'}) 0.4259815353434533
# frozenset({'SpermWhale', 'Chimpanzee'}) 0.5536373406648636
# frozenset({'SpermWhale', 'HairyArma'}) 0.3555931830778718
# frozenset({'Sloth', 'SpermWhale'}) 0.3458994347602129
# frozenset({'HumpbackW', 'FlyingLem'}) 0.32477539870887995
# frozenset({'HowlerMon', 'HumpbackW'}) 0.4010772332549095
# frozenset({'HumpbackW', 'Rhesus'}) 0.36245305091142654
# frozenset({'Orangutan', 'HumpbackW'}) 0.48087427695281804
# frozenset({'HumpbackW', 'Gorilla'}) 0.4392048856243491
# frozenset({'Human', 'HumpbackW'}) 0.2896405019564554
# frozenset({'HumpbackW', 'Chimpanzee'}) 0.4545900959055871
# frozenset({'HumpbackW', 'HairyArma'}) 0.3447062438353896
# frozenset({'Sloth', 'HumpbackW'}) 0.3543401947245002
# frozenset({'HowlerMon', 'FlyingLem'}) 0.25459117349237204
# frozenset({'Rhesus', 'FlyingLem'}) 0.23766956012696028
# frozenset({'Orangutan', 'FlyingLem'}) 0.349954173900187
# frozenset({'Gorilla', 'FlyingLem'}) 0.39310126192867756
# frozenset({'Human', 'FlyingLem'}) 0.21070618776138872
# frozenset({'Chimpanzee', 'FlyingLem'}) 0.3784169510472566
# frozenset({'FlyingLem', 'HairyArma'}) 0.264177531003952
# frozenset({'Sloth', 'FlyingLem'}) 0.2589063150808215
# frozenset({'HowlerMon', 'Rhesus'}) 0.2684659752994776
# frozenset({'HowlerMon', 'Orangutan'}) 0.2795006309170276
# frozenset({'HowlerMon', 'Gorilla'}) 0.4359132098034024
# frozenset({'HowlerMon', 'Human'}) 0.26698668499011546
# frozenset({'HowlerMon', 'Chimpanzee'}) 0.34737619245424867
# frozenset({'HowlerMon', 'HairyArma'}) 0.21499535162001848
# frozenset({'HowlerMon', 'Sloth'}) 0.22032837104052305
# frozenset({'Orangutan', 'Rhesus'}) 0.26895944005809724
# frozenset({'Rhesus', 'Gorilla'}) 0.49425563775002956
# frozenset({'Human', 'Rhesus'}) 0.35708797513507307
# frozenset({'Rhesus', 'Chimpanzee'}) 0.39859983837231994
# frozenset({'Rhesus', 'HairyArma'}) 0.22687818761914968
# frozenset({'Sloth', 'Rhesus'}) 0.20626920461654663
# frozenset({'Orangutan', 'Gorilla'}) 0.33472885470837355
# frozenset({'Human', 'Orangutan'}) 0.3979314119787887
# frozenset({'Orangutan', 'Chimpanzee'}) 0.4001199745107442
# frozenset({'Orangutan', 'HairyArma'}) 0.4544921740889549
# frozenset({'Sloth', 'Orangutan'}) 0.3367447443306446
# frozenset({'Human', 'Gorilla'}) 0.3880753703415394
# frozenset({'Gorilla', 'Chimpanzee'}) 0.5287715718150139
# frozenset({'Gorilla', 'HairyArma'}) 0.48486059438437223
# frozenset({'Sloth', 'Gorilla'}) 0.4623787496238947
# frozenset({'Human', 'Chimpanzee'}) 0.4152767937630415
# frozenset({'Human', 'HairyArma'}) 0.4971983730792999
# frozenset({'Sloth', 'Human'}) 0.39143992215394974
# frozenset({'Chimpanzee', 'HairyArma'}) 0.501513009890914
# frozenset({'Sloth', 'Chimpanzee'}) 0.46140935830771923
# frozenset({'Sloth', 'HairyArma'}) 0.3484824215993285
# Cut value: 17.36841092829127, Partition:
# (['HairyArma', 'Human', 'Llama', 'Orangutan', 'Pangolin', 'Sloth'], ['Chimpanzee', 'FlyingLem', 'Gorilla', 'Horse', 'HowlerMon', 'HumpbackW', 'Rhesus', 'Rhino', 'SpermWhale'])
# Graph:
# frozenset({'Orangutan', 'Llama'}) 0.14509125612676144
# frozenset({'Pangolin', 'Orangutan'}) 0.15683835744857788
# frozenset({'Pangolin', 'Llama'}) 0.08369183912873268
# frozenset({'Human', 'Llama'}) 0.1332182101905346
# frozenset({'Pangolin', 'Human'}) 0.15462970361113548
# frozenset({'Llama', 'HairyArma'}) 0.09940852131694555
# frozenset({'Pangolin', 'HairyArma'}) 0.070977333933115
# frozenset({'Sloth', 'Llama'}) 0.08934504259377718
# frozenset({'Pangolin', 'Sloth'}) 0.0699175437912345
# frozenset({'Orangutan', 'Human'}) 0.1036083260551095
# frozenset({'Orangutan', 'HairyArma'}) 0.16396864503622055
# frozenset({'Sloth', 'Orangutan'}) 0.061477918177843094
# frozenset({'Human', 'HairyArma'}) 0.1645253635942936
# frozenset({'Sloth', 'Human'}) 0.06820550002157688
# frozenset({'Sloth', 'HairyArma'}) 0.11332977842539549
# Cut value: 0.9610736100003123, Partition:
# (['HairyArma', 'Llama', 'Sloth'], ['Human', 'Orangutan', 'Pangolin'])
# Graph:
# frozenset({'Sloth', 'HairyArma'}) 0.014991340227425098
# frozenset({'Sloth', 'Llama'}) 0.015370783396065235
# frozenset({'Llama', 'HairyArma'}) 0.013253129087388515
# Cut value: 0.028244469314813614, Partition:
# (['Llama', 'Sloth'], ['HairyArma'])
# Graph:
# frozenset({'Orangutan', 'Human'}) 0.03143986314535141
# frozenset({'Pangolin', 'Human'}) 0.08926823735237122
# frozenset({'Pangolin', 'Orangutan'}) 0.09458994120359421
# Cut value: 0.12070810049772263, Partition:
# (['Human'], ['Orangutan', 'Pangolin'])
# Graph:
# frozenset({'Rhino', 'SpermWhale'}) 0.2252857917919755
# frozenset({'Horse', 'SpermWhale'}) 0.17243302473798394
# frozenset({'Rhino', 'Horse'}) 0.12120927311480045
# frozenset({'Rhino', 'HumpbackW'}) 0.2223183885216713
# frozenset({'Horse', 'HumpbackW'}) 0.16919252462685108
# frozenset({'Rhino', 'FlyingLem'}) 0.1308263149112463
# frozenset({'Horse', 'FlyingLem'}) 0.11388987395912409
# frozenset({'Rhino', 'HowlerMon'}) 0.13436456583440304
# frozenset({'HowlerMon', 'Horse'}) 0.13151528406888247
# frozenset({'Rhino', 'Rhesus'}) 0.13085658010095358
# frozenset({'Horse', 'Rhesus'}) 0.16145382728427649
# frozenset({'Rhino', 'Gorilla'}) 0.22385977674275637
# frozenset({'Horse', 'Gorilla'}) 0.21507056802511215
# frozenset({'Rhino', 'Chimpanzee'}) 0.2152146464213729
# frozenset({'Horse', 'Chimpanzee'}) 0.23238886892795563
# frozenset({'HumpbackW', 'SpermWhale'}) 0.3380967192351818
# frozenset({'SpermWhale', 'FlyingLem'}) 0.24564909376204014
# frozenset({'HowlerMon', 'SpermWhale'}) 0.24842644855380058
# frozenset({'SpermWhale', 'Rhesus'}) 0.23150204680860043
# frozenset({'SpermWhale', 'Gorilla'}) 0.305596343241632
# frozenset({'SpermWhale', 'Chimpanzee'}) 0.3293107785284519
# frozenset({'HumpbackW', 'FlyingLem'}) 0.22695794608443975
# frozenset({'HowlerMon', 'HumpbackW'}) 0.2633672524243593
# frozenset({'HumpbackW', 'Rhesus'}) 0.21132038906216621
# frozenset({'HumpbackW', 'Gorilla'}) 0.3062345087528229
# frozenset({'HumpbackW', 'Chimpanzee'}) 0.30537386145442724
# frozenset({'HowlerMon', 'FlyingLem'}) 0.13500551041215658
# frozenset({'Rhesus', 'FlyingLem'}) 0.12563826236873865
# frozenset({'Gorilla', 'FlyingLem'}) 0.21916635893285275
# frozenset({'Chimpanzee', 'FlyingLem'}) 0.21358319651335478
# frozenset({'HowlerMon', 'Rhesus'}) 0.13541374076157808
# frozenset({'HowlerMon', 'Gorilla'}) 0.28037177957594395
# frozenset({'HowlerMon', 'Chimpanzee'}) 0.20539455488324165
# frozenset({'Rhesus', 'Gorilla'}) 0.23048454709351063
# frozenset({'Rhesus', 'Chimpanzee'}) 0.19221884198486805
# frozenset({'Gorilla', 'Chimpanzee'}) 0.29537514597177505
# Cut value: 3.5527782985009253, Partition:
# (['Chimpanzee', 'Horse', 'Rhesus'], ['FlyingLem', 'Gorilla', 'HowlerMon', 'HumpbackW', 'Rhino', 'SpermWhale'])
# Graph:
# frozenset({'Rhesus', 'Chimpanzee'}) 0.009425983764231205
# frozenset({'Horse', 'Chimpanzee'}) 0.035928305238485336
# frozenset({'Horse', 'Rhesus'}) 0.039157379418611526
# Cut value: 0.04535428900271654, Partition:
# (['Chimpanzee'], ['Horse', 'Rhesus'])
# Graph:
# frozenset({'HumpbackW', 'SpermWhale'}) 0.20271680131554604
# frozenset({'Rhino', 'HumpbackW'}) 0.158327154815197
# frozenset({'Rhino', 'SpermWhale'}) 0.16706102807074785
# frozenset({'SpermWhale', 'FlyingLem'}) 0.1777829322963953
# frozenset({'Rhino', 'FlyingLem'}) 0.06811921671032906
# frozenset({'HowlerMon', 'SpermWhale'}) 0.19708679523319006
# frozenset({'Rhino', 'HowlerMon'}) 0.07718746922910213
# frozenset({'SpermWhale', 'Gorilla'}) 0.16629038378596306
# frozenset({'Rhino', 'Gorilla'}) 0.07921248581260443
# frozenset({'HumpbackW', 'FlyingLem'}) 0.16440887097269297
# frozenset({'HowlerMon', 'HumpbackW'}) 0.20952757075428963
# frozenset({'HumpbackW', 'Gorilla'}) 0.168001270852983
# frozenset({'HowlerMon', 'FlyingLem'}) 0.07968265004456043
# frozenset({'Gorilla', 'FlyingLem'}) 0.07673683017492294
# frozenset({'HowlerMon', 'Gorilla'}) 0.14309119246900082
# Cut value: 1.201649441383779, Partition:
# (['FlyingLem', 'Rhino', 'SpermWhale'], ['Gorilla', 'HowlerMon', 'HumpbackW'])
# Graph:
# frozenset({'SpermWhale', 'FlyingLem'}) 0.01436785887926817
# frozenset({'Rhino', 'FlyingLem'}) 0.018447455018758774
# frozenset({'Rhino', 'SpermWhale'}) 0.015097719617187977
# Cut value: 0.029465578496456146, Partition:
# (['SpermWhale'], ['FlyingLem', 'Rhino'])
# Graph:
# frozenset({'HowlerMon', 'Gorilla'}) 0.046799734234809875
# frozenset({'HumpbackW', 'Gorilla'}) 0.009502761997282505
# frozenset({'HowlerMon', 'HumpbackW'}) 0.01609930396080017
# Cut value: 0.025602065958082676, Partition:
# (['HumpbackW'], ['Gorilla', 'HowlerMon'])
#                                         /-Llama
#                               /--------|
#                     /--------|          \-Sloth
#                    |         |
#           /--------|          \-HairyArma
#          |         |
#          |         |          /-Human
#          |          \--------|
#          |                   |          /-Orangutan
#          |                    \--------|
# ---------|                              \-Pangolin
#          |
#          |                    /-Chimpanzee
#          |          /--------|
#          |         |         |          /-Horse
#          |         |          \--------|
#          |         |                    \-Rhesus
#           \--------|
#                    |                    /-SpermWhale
#                    |          /--------|
#                    |         |         |          /-FlyingLem
#                    |         |          \--------|
#                     \--------|                    \-Rhino
#                              |
#                              |          /-HumpbackW
#                               \--------|
#                                        |          /-Gorilla
#                                         \--------|
#                                                   \-HowlerMon
# CPU times: user 7min 10s, sys: 58.7 s, total: 8min 9s
# Wall time: 4min 51s

# %%
# %%time
aln = load_aligned_seqs('brca1.fasta', moltype='dna')
subaln = aln.get_similar(aln.take_seqs(['Human']).seqs[0], min_similarity=0.80)
triples = get_triples(subaln, codon_position=3, verbose=True)
losses, params = fit_triples(triples, verbose=True, steps=3000, sharesies=[0]*len(triples))  # , sharesies=sharesies)  # , sharesies=[0]*len(triples))
# Out:
# Got 745 positions
# Fitting 7140 triples using 1 rate matrix(es)
# Step: 1, initial loss: 932.1404418945312
# Step: 101, initial loss: 193.00250244140625
# Step: 201, initial loss: 86.87216186523438
# Step: 301, initial loss: 59.58234786987305
# Step: 401, initial loss: 48.13275909423828
# Step: 501, initial loss: 42.375404357910156
# Step: 601, initial loss: 39.149967193603516
# Step: 701, initial loss: 37.17272186279297
# Step: 801, initial loss: 35.861366271972656
# Step: 901, initial loss: 34.932430267333984
# Step: 1001, initial loss: 34.23923110961914
# Step: 1101, initial loss: 33.700767517089844
# Step: 1201, initial loss: 33.269264221191406
# Step: 1301, initial loss: 32.914608001708984
# Step: 1401, initial loss: 32.616668701171875
# Step: 1501, initial loss: 32.36134338378906
# Step: 1601, initial loss: 32.13839340209961
# Step: 1701, initial loss: 31.940216064453125
# Step: 1801, initial loss: 31.761077880859375
# Step: 1901, initial loss: 31.59670639038086
# Step: 2001, initial loss: 31.443927764892578
# Step: 2101, initial loss: 31.30051612854004
# Step: 2201, initial loss: 31.16501235961914
# Step: 2301, initial loss: 31.036632537841797
# Step: 2401, initial loss: 30.91503143310547
# Step: 2501, initial loss: 30.800247192382812
# Step: 2601, initial loss: 30.692468643188477
# Step: 2701, initial loss: 30.591886520385742
# Step: 2801, initial loss: 30.49860954284668
# Step: 2901, initial loss: 30.412588119506836
# WARNING:tensorflow:11 out of the last 11 calls to <function pfor.<locals>.f at 0x7f82e0207670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# CPU times: user 3h 22min 6s, sys: 11min 42s, total: 3h 33min 48s
# Wall time: 2h 59min 45s

# %%
list(zip((n for n, _ in triples), losses, [np.array([p.numpy() for p in param[4:10]]) for param in params]))
# Out:
# [(('FlyingFox', 'FreeTaile', 'LittleBro'),
#   0.005206179,
#   array([0.01996232, 0.00444928, 0.0006153 , 0.10571226, 0.01687876,
#          0.04955609], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'TombBat'),
#   0.0059564696,
#   array([0.02457512, 0.00343366, 0.00521923, 0.10511307, 0.01736984,
#          0.01263802], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'LeafNose'),
#   0.0047125067,
#   array([0.00923002, 0.0102211 , 0.00889685, 0.07330912, 0.04733199,
#          0.06368802], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Horse'),
#   0.004242083,
#   array([0.01965397, 0.0075755 , 0.01195962, 0.09485808, 0.02642714,
#          0.07972658], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Rhino'),
#   0.0029441984,
#   array([0.01914574, 0.03133254, 0.03313847, 0.07314131, 0.04749844,
#          0.07142801], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Pangolin'),
#   0.0036895326,
#   array([0.01842042, 0.01126666, 0.07119681, 0.07517575, 0.04548229,
#          0.08318905], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Cat'),
#   0.0038568,
#   array([0.01830025, 0.0090579 , 0.00729728, 0.06909135, 0.05152285,
#          0.17880699], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Dog'),
#   0.0041966764,
#   array([0.02091756, 0.0031774 , 0.00611837, 0.09044128, 0.03058694,
#          0.2065649 ], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Llama'),
#   0.0038123706,
#   array([0.02038549, 0.0138256 , 0.00698937, 0.06602424, 0.05457824,
#          0.14804569], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Pig'),
#   0.0048892433,
#   array([0.00635365, 0.0116441 , 0.00598299, 0.07346228, 0.04718008,
#          0.1856313 ], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Cow'),
#   0.00524673,
#   array([0.01811855, 0.01439376, 0.00999364, 0.07506398, 0.04559293,
#          0.18981275], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Hippo'),
#   0.004035631,
#   array([0.01899164, 0.01258943, 0.01330995, 0.06859866, 0.05201326,
#          0.15791658], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'SpermWhale'),
#   0.0035913386,
#   array([0.02009337, 0.01053756, 0.03677357, 0.07080041, 0.04982301,
#          0.10713503], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'HumpbackW'),
#   0.0035220238,
#   array([0.02010577, 0.0105462 , 0.03781684, 0.07033633, 0.05028438,
#          0.10814556], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Mole'),
#   0.0044075353,
#   array([0.01826716, 0.01083945, 0.038767  , 0.07077529, 0.04984797,
#          0.18567544], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'TreeShrew'),
#   0.0048156735,
#   array([0.01228272, 0.00995617, 0.12989269, 0.07926269, 0.04144685,
#          0.13359855], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'FlyingLem'),
#   0.003326592,
#   array([0.01924608, 0.00672076, 0.08373155, 0.07459731, 0.04605509,
#          0.11345637], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Galago'),
#   0.003534996,
#   array([0.01299042, 0.00817452, 0.13992278, 0.06389689, 0.05670063,
#          0.14442065], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'HowlerMon'),
#   0.004252611,
#   array([0.0170151 , 0.01429086, 0.08885899, 0.06521464, 0.05538566,
#          0.11748675], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Rhesus'),
#   0.003640424,
#   array([0.0139132 , 0.02866813, 0.1085709 , 0.06828984, 0.05232072,
#          0.13164242], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Orangutan'),
#   0.0038330653,
#   array([0.01589441, 0.01008781, 0.09648546, 0.06958697, 0.0510297 ,
#          0.14769098], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Gorilla'),
#   0.0038288261,
#   array([0.01558232, 0.01095556, 0.09842887, 0.07147045, 0.04915718,
#          0.13286816], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Human'),
#   0.0040445137,
#   array([0.01439339, 0.01097279, 0.10059633, 0.06903004, 0.05158387,
#          0.1256535 ], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Chimpanzee'),
#   0.003785208,
#   array([0.01610707, 0.01093189, 0.09491668, 0.07069928, 0.04992352,
#          0.13161625], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'FlyingSqu'),
#   0.004654262,
#   array([0.0235428 , 0.00495583, 0.00989342, 0.06816991, 0.05244015,
#          0.18265365], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'NineBande'),
#   0.0037863185,
#   array([0.02161752, 0.00670204, 0.07882739, 0.07346323, 0.04717916,
#          0.11972316], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'HairyArma'),
#   0.0033886498,
#   array([0.01991615, 0.01069621, 0.07320677, 0.07265601, 0.04797997,
#          0.11383876], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Anteater'),
#   0.004930648,
#   array([0.02006714, 0.0123211 , 0.0407506 , 0.07318048, 0.04745958,
#          0.13123487], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Sloth'),
#   0.0043932362,
#   array([0.0189933 , 0.01198045, 0.01794676, 0.06905913, 0.05155492,
#          0.12547944], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Dugong'),
#   0.0043735034,
#   array([0.01321984, 0.01137527, 0.0087758 , 0.0768318 , 0.04384446,
#          0.17595667], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Manatee'),
#   0.0044671516,
#   array([0.01355303, 0.01236326, 0.00880802, 0.07484489, 0.04580988,
#          0.16251723], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'AfricanEl'),
#   0.004502296,
#   array([0.01497455, 0.01008065, 0.02505398, 0.07643988, 0.04423176,
#          0.18421507], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'AsianElep'),
#   0.004278429,
#   array([0.01484875, 0.0098127 , 0.01955939, 0.07559459, 0.04506774,
#          0.19510421], dtype=float32)),
#  (('FlyingFox', 'FreeTaile', 'Aardvark'),
#   0.0057756337,
#   array([0.00246071, 0.00436149, 0.11092564, 0.06526687, 0.05533357,
#          0.18678157], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'TombBat'),
#   0.0047832085,
#   array([0.02563559, 0.00400273, 0.01206602, 0.09132972, 0.06388559,
#          0.02404753], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'LeafNose'),
#   0.004046023,
#   array([0.00814265, 0.00343776, 0.00875738, 0.06309902, 0.09211759,
#          0.07389878], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Horse'),
#   0.003846928,
#   array([0.01496268, 0.00450595, 0.01071452, 0.08810201, 0.06710905,
#          0.08648165], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Rhino'),
#   0.0027840335,
#   array([0.01447575, 0.01004706, 0.03240805, 0.06672074, 0.08849078,
#          0.07785085], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Pangolin'),
#   0.003142135,
#   array([0.01245732, 0.00311794, 0.07493929, 0.07075541, 0.08445261,
#          0.08761154], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Cat'),
#   0.003462332,
#   array([0.01336079, 0.00319834, 0.00829824, 0.06431924, 0.09089541,
#          0.1835852 ], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Dog'),
#   0.0033809457,
#   array([0.01260521, 0.00298981, 0.02928838, 0.07268821, 0.08251876,
#          0.22432372], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Llama'),
#   0.0035761097,
#   array([0.01427118, 0.00380789, 0.01929139, 0.05388716, 0.10135642,
#          0.16021496], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Pig'),
#   0.0045093205,
#   array([0.00516681, 0.00352466, 0.02080312, 0.07344549, 0.0817612 ,
#          0.18564813], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Cow'),
#   0.0043497486,
#   array([0.01349562, 0.00350784, 0.03933684, 0.05930835, 0.09591635,
#          0.20558947], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Hippo'),
#   0.003653535,
#   array([0.01290376, 0.00388163, 0.04300687, 0.06767943, 0.08753107,
#          0.1588368 ], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'SpermWhale'),
#   0.003272044,
#   array([0.01765639, 0.00380648, 0.0341913 , 0.05965462, 0.09556921,
#          0.11829795], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'HumpbackW'),
#   0.0032190739,
#   array([0.01745678, 0.00360273, 0.03492288, 0.06023403, 0.09498838,
#          0.11826316], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Mole'),
#   0.0037748762,
#   array([0.01843639, 0.00301166, 0.0383571 , 0.06822988, 0.08698008,
#          0.18822332], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'TreeShrew'),
#   0.004023864,
#   array([0.00935084, 0.00564723, 0.13905041, 0.06210074, 0.09311768,
#          0.15077697], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'FlyingLem'),
#   0.0032105683,
#   array([0.01226782, 0.00358384, 0.06932501, 0.06460763, 0.09060657,
#          0.12345587], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Galago'),
#   0.003173105,
#   array([0.01031734, 0.00309464, 0.14538644, 0.05907623, 0.09614907,
#          0.14925173], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'HowlerMon'),
#   0.0037735803,
#   array([0.01509204, 0.00405377, 0.08295123, 0.05822131, 0.09700637,
#          0.12449499], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Rhesus'),
#   0.003336647,
#   array([0.01311268, 0.0075624 , 0.10688183, 0.06557702, 0.08963586,
#          0.13435861], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Orangutan'),
#   0.0033521182,
#   array([0.01225537, 0.00410954, 0.09241688, 0.07020316, 0.08500522,
#          0.1470742 ], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Gorilla'),
#   0.0034071836,
#   array([0.01309585, 0.00391236, 0.08896362, 0.06478144, 0.09043252,
#          0.13956465], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Human'),
#   0.0036169284,
#   array([0.01186785, 0.00407545, 0.09034447, 0.0626608 , 0.09255658,
#          0.13203171], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Chimpanzee'),
#   0.0033293641,
#   array([0.01353375, 0.00375915, 0.08608047, 0.06382816, 0.09138724,
#          0.13849577], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'FlyingSqu'),
#   0.0033543545,
#   array([0.01033333, 0.00260727, 0.10655355, 0.07033546, 0.08487283,
#          0.18048596], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'NineBande'),
#   0.00463276,
#   array([0.01664939, 0.00357774, 0.06382307, 0.0813252 , 0.07388134,
#          0.11185774], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'HairyArma'),
#   0.0030145114,
#   array([0.01538103, 0.00330999, 0.06462001, 0.07279719, 0.08240975,
#          0.11369748], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Anteater'),
#   0.003652201,
#   array([0.01484282, 0.00327536, 0.08152403, 0.06413539, 0.09107951,
#          0.1402897 ], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Sloth'),
#   0.0036401988,
#   array([0.01498225, 0.00342605, 0.04477703, 0.06567013, 0.08954264,
#          0.12887247], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Dugong'),
#   0.0037175696,
#   array([0.01070587, 0.00359081, 0.02697614, 0.06609571, 0.08911654,
#          0.18670164], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Manatee'),
#   0.0037357106,
#   array([0.01063162, 0.00386217, 0.02580895, 0.06211634, 0.09310205,
#          0.17526026], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'AfricanEl'),
#   0.004003779,
#   array([0.01234102, 0.0029418 , 0.020417  , 0.06476831, 0.09044567,
#          0.19589724], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'AsianElep'),
#   0.0037849569,
#   array([0.01178307, 0.00290209, 0.01637461, 0.06467039, 0.09054375,
#          0.20603876], dtype=float32)),
#  (('FlyingFox', 'LittleBro', 'Aardvark'),
#   0.004979932,
#   array([0.00180937, 0.00264981, 0.1089182 , 0.05370089, 0.10154355,
#          0.19837955], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'LeafNose'),
#   0.0046360195,
#   array([0.01073766, 0.04155485, 0.02334783, 0.05450457, 0.05999321,
#          0.0825145 ], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Horse'),
#   0.00556794,
#   array([0.05697358, 0.01861278, 0.0065814 , 0.07208367, 0.04249735,
#          0.10250452], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Rhino'),
#   0.0035256878,
#   array([0.02561348, 0.04238768, 0.00962924, 0.05648576, 0.05800972,
#          0.08810575], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Pangolin'),
#   0.0040423125,
#   array([0.02528219, 0.03628976, 0.0695051 , 0.0627865 , 0.05171907,
#          0.09558988], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Cat'),
#   0.004402494,
#   array([0.02036538, 0.02795905, 0.00570928, 0.06131371, 0.05318706,
#          0.1865964 ], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Dog'),
#   0.0045495695,
#   array([0.02708847, 0.00814017, 0.00380892, 0.06515975, 0.04935708,
#          0.23186006], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Llama'),
#   0.004319457,
#   array([0.02470798, 0.04383401, 0.00643589, 0.05110721, 0.06340086,
#          0.16300964], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Pig'),
#   0.005081948,
#   array([0.0084868 , 0.03326909, 0.00530099, 0.06314609, 0.05136091,
#          0.19595918], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Cow'),
#   0.006662322,
#   array([0.02681893, 0.01844433, 0.00923395, 0.05104239, 0.06346595,
#          0.21388975], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Hippo'),
#   0.0045007626,
#   array([0.02720462, 0.03535951, 0.01015851, 0.05720693, 0.05728837,
#          0.16933063], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'SpermWhale'),
#   0.004234717,
#   array([0.02640169, 0.03916525, 0.00860626, 0.05481356, 0.05968369,
#          0.12315501], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'HumpbackW'),
#   0.0041327216,
#   array([0.02602908, 0.03811022, 0.00839695, 0.05497144, 0.05952556,
#          0.12354255], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Mole'),
#   0.004968481,
#   array([0.02440537, 0.01402891, 0.02745915, 0.04955317, 0.06496252,
#          0.20695983], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'TreeShrew'),
#   0.0043903794,
#   array([0.04131205, 0.0329343 , 0.14965142, 0.05320826, 0.06129246,
#          0.15969834], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'FlyingLem'),
#   0.0041646897,
#   array([0.02233594, 0.03643837, 0.05612761, 0.05561142, 0.05888475,
#          0.13247491], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Galago'),
#   0.004366099,
#   array([0.01559426, 0.02796905, 0.14140446, 0.05984366, 0.05465385,
#          0.1484823 ], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'HowlerMon'),
#   0.0048002126,
#   array([0.01487067, 0.04700685, 0.07699705, 0.04609624, 0.06844437,
#          0.13669041], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Rhesus'),
#   0.0044681095,
#   array([0.01345109, 0.04052237, 0.0964791 , 0.05109681, 0.0634113 ,
#          0.14888516], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Orangutan'),
#   0.004488885,
#   array([0.01520806, 0.03409468, 0.08190266, 0.05266513, 0.06183718,
#          0.16465506], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Gorilla'),
#   0.0044116853,
#   array([0.01494518, 0.0392081 , 0.08158906, 0.05398042, 0.06051842,
#          0.15039566], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Human'),
#   0.00466161,
#   array([0.01270862, 0.04003387, 0.0835164 , 0.05160354, 0.06290247,
#          0.1431275 ], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Chimpanzee'),
#   0.0044106166,
#   array([0.01535614, 0.03905556, 0.07862492, 0.05324678, 0.06125385,
#          0.14910907], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'FlyingSqu'),
#   0.004891173,
#   array([0.02582016, 0.02983412, 0.03321813, 0.05857075, 0.05592513,
#          0.1922705 ], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'NineBande'),
#   0.0044550775,
#   array([0.02547315, 0.02985094, 0.06081572, 0.05677088, 0.05772449,
#          0.1364433 ], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'HairyArma'),
#   0.003978398,
#   array([0.02321477, 0.03343393, 0.06109368, 0.05573513, 0.05876091,
#          0.1307906 ], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Anteater'),
#   0.005341052,
#   array([0.02580657, 0.03406309, 0.02833537, 0.0587731 , 0.05572296,
#          0.14566365], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Sloth'),
#   0.0048515275,
#   array([0.02553426, 0.03658269, 0.01201389, 0.05397511, 0.06052374,
#          0.14059877], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Dugong'),
#   0.0042428277,
#   array([0.01817957, 0.03727649, 0.02791563, 0.06073777, 0.05376155,
#          0.19206914], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Manatee'),
#   0.00436926,
#   array([0.01843097, 0.03886497, 0.02578435, 0.05957748, 0.0549196 ,
#          0.17780495], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'AfricanEl'),
#   0.0056672557,
#   array([0.02231024, 0.0159466 , 0.0221369 , 0.06094397, 0.05355585,
#          0.19972876], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'AsianElep'),
#   0.005445437,
#   array([0.02198583, 0.01569316, 0.01754558, 0.06018081, 0.05431731,
#          0.21053717], dtype=float32)),
#  (('FlyingFox', 'TombBat', 'Aardvark'),
#   0.005703713,
#   array([0.0034552 , 0.03889012, 0.11197152, 0.04880255, 0.06571762,
#          0.20330751], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Horse'),
#   0.004763075,
#   array([0.00960475, 0.0088582 , 0.01673704, 0.07270371, 0.06429282,
#          0.10188407], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Rhino'),
#   0.0041528842,
#   array([0.00851627, 0.02683191, 0.01201566, 0.06807037, 0.06892427,
#          0.07650021], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Pangolin'),
#   0.0043829046,
#   array([0.00647406, 0.00535051, 0.07784615, 0.06923182, 0.06776287,
#          0.08913628], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Cat'),
#   0.0044667767,
#   array([0.01591286, 0.00631361, 0.01091543, 0.08599303, 0.05104312,
#          0.16189714], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Dog'),
#   0.0036256663,
#   array([0.02146475, 0.00463454, 0.03974117, 0.07412823, 0.06286987,
#          0.2228828 ], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Llama'),
#   0.0051627303,
#   array([0.00655431, 0.00357742, 0.01779049, 0.07390898, 0.06308883,
#          0.14015351], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Pig'),
#   0.0040021557,
#   array([0.02167763, 0.00460677, 0.01710243, 0.07841191, 0.05859404,
#          0.18067916], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Cow'),
#   0.005664007,
#   array([0.00636795, 0.00909412, 0.0399375 , 0.07409894, 0.06289911,
#          0.19077834], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Hippo'),
#   0.004465495,
#   array([0.00660367, 0.0067905 , 0.04907611, 0.07010417, 0.06689075,
#          0.15640959], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'SpermWhale'),
#   0.0048385295,
#   array([0.00813543, 0.0031844 , 0.02509071, 0.07305066, 0.06394621,
#          0.10488311], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'HumpbackW'),
#   0.0048012007,
#   array([0.00800421, 0.00335735, 0.02186825, 0.07462132, 0.06237742,
#          0.10385762], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Mole'),
#   0.0048231184,
#   array([0.00640022, 0.00763503, 0.04619374, 0.05295959, 0.08406632,
#          0.20353296], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'TreeShrew'),
#   0.0052724197,
#   array([0.00454878, 0.00800845, 0.13667876, 0.06397355, 0.0730233 ,
#          0.14890075], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'FlyingLem'),
#   0.004290005,
#   array([0.00600566, 0.00493213, 0.07322217, 0.06441804, 0.07257838,
#          0.12364576], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Galago'),
#   0.0045543257,
#   array([0.00577321, 0.00364993, 0.13951817, 0.06476334, 0.07223278,
#          0.14355278], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'HowlerMon'),
#   0.005201497,
#   array([0.00665724, 0.0084918 , 0.07601997, 0.06245609, 0.07454251,
#          0.12024996], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Rhesus'),
#   0.0047139795,
#   array([0.00469926, 0.02056759, 0.10216855, 0.06335682, 0.07364067,
#          0.13658233], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Orangutan'),
#   0.004989672,
#   array([0.00507445, 0.00393317, 0.07824259, 0.06957336, 0.0674214 ,
#          0.1477046 ], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Gorilla'),
#   0.004927302,
#   array([0.00547231, 0.00628416, 0.07986958, 0.06754383, 0.06945088,
#          0.13679855], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Human'),
#   0.0049492535,
#   array([0.00452877, 0.00629297, 0.08356425, 0.06496415, 0.07203183,
#          0.12972447], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Chimpanzee'),
#   0.004859951,
#   array([0.00557469, 0.00619931, 0.07721619, 0.06715764, 0.06983718,
#          0.13516149], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'FlyingSqu'),
#   0.0046789553,
#   array([0.00470304, 0.00321444, 0.1085835 , 0.06289902, 0.07409903,
#          0.18793216], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'NineBande'),
#   0.0050154612,
#   array([0.0068838 , 0.00369888, 0.06753298, 0.06881762, 0.06817701,
#          0.12437256], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'HairyArma'),
#   0.0044907276,
#   array([0.00650939, 0.00410468, 0.07309841, 0.07133041, 0.06566508,
#          0.11516535], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Anteater'),
#   0.004865608,
#   array([0.00626492, 0.00790478, 0.09259617, 0.06704952, 0.06994534,
#          0.13737144], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Sloth'),
#   0.005074446,
#   array([0.00625295, 0.00649689, 0.04811306, 0.06637971, 0.07061539,
#          0.1281619 ], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Dugong'),
#   0.0042457543,
#   array([0.01657206, 0.00357546, 0.02859035, 0.07788799, 0.05911668,
#          0.1749    ], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Manatee'),
#   0.0043434156,
#   array([0.0165868 , 0.00418123, 0.02780029, 0.07661197, 0.06039003,
#          0.16074926], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'AfricanEl'),
#   0.0055694957,
#   array([0.00558824, 0.00349466, 0.02357722, 0.07347946, 0.06351785,
#          0.18717714], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'AsianElep'),
#   0.005332908,
#   array([0.00581716, 0.00306021, 0.0179363 , 0.07263666, 0.06435982,
#          0.19806394], dtype=float32)),
#  (('FlyingFox', 'LeafNose', 'Aardvark'),
#   0.004952358,
#   array([0.00433001, 0.00692201, 0.10606208, 0.05963529, 0.07736823,
#          0.19242424], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Rhino'),
#   0.0034037842,
#   array([0.07183851, 0.0032514 , 0.00145286, 0.12392179, 0.05072158,
#          0.0218289 ], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Pangolin'),
#   0.0035197996,
#   array([0.02028465, 0.0038742 , 0.04834012, 0.10432535, 0.07026427,
#          0.05407679], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Cat'),
#   0.0039816643,
#   array([0.02130795, 0.00400975, 0.00636551, 0.09704117, 0.07754415,
#          0.15084776], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Dog'),
#   0.004119737,
#   array([0.02031947, 0.00462963, 0.0062545 , 0.1193916 , 0.05522893,
#          0.17761347], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Llama'),
#   0.004503756,
#   array([0.05277237, 0.0055033 , 0.00456632, 0.10804015, 0.06655335,
#          0.10601662], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Pig'),
#   0.0039070384,
#   array([0.0624433 , 0.00394913, 0.00432805, 0.09187249, 0.08271154,
#          0.16721568], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Cow'),
#   0.0052759373,
#   array([0.02667462, 0.00320791, 0.0062466 , 0.10866053, 0.06593382,
#          0.1562109 ], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Hippo'),
#   0.0036415418,
#   array([0.06131436, 0.00694327, 0.00725171, 0.09825698, 0.07632885,
#          0.12824832], dtype=float32)),
#  (('FlyingFox', 'Horse', 'SpermWhale'),
#   0.0032516601,
#   array([0.05855867, 0.0081853 , 0.02220793, 0.09931474, 0.07527155,
#          0.07861638], dtype=float32)),
#  (('FlyingFox', 'Horse', 'HumpbackW'),
#   0.0031350302,
#   array([0.06048368, 0.00711458, 0.01821303, 0.09879073, 0.07579533,
#          0.07968613], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Mole'),
#   0.0039741537,
#   array([0.01746724, 0.01415835, 0.03244983, 0.07772104, 0.09686425,
#          0.17872547], dtype=float32)),
#  (('FlyingFox', 'Horse', 'TreeShrew'),
#   0.0063167047,
#   array([0.06226928, 0.00694299, 0.06379578, 0.10851065, 0.06608348,
#          0.10434744], dtype=float32)),
#  (('FlyingFox', 'Horse', 'FlyingLem'),
#   0.004376134,
#   array([0.01746204, 0.009714  , 0.06515955, 0.10820406, 0.06638967,
#          0.07984735], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Galago'),
#   0.0040186653,
#   array([0.01549443, 0.00399223, 0.10681543, 0.09737563, 0.07720982,
#          0.11092583], dtype=float32)),
#  (('FlyingFox', 'Horse', 'HowlerMon'),
#   0.0042136093,
#   array([0.0206694 , 0.00376347, 0.06030524, 0.09491975, 0.07966492,
#          0.08776914], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Rhesus'),
#   0.0040500024,
#   array([0.01844762, 0.00533966, 0.08187022, 0.09752139, 0.07706413,
#          0.10240096], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Orangutan'),
#   0.0039122514,
#   array([0.01862372, 0.00395665, 0.06639571, 0.10330735, 0.07128143,
#          0.11396153], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Gorilla'),
#   0.0039550792,
#   array([0.01871369, 0.00410856, 0.06457008, 0.1053084 , 0.0692821 ,
#          0.09902308], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Human'),
#   0.0040673325,
#   array([0.01427727, 0.00412593, 0.07045628, 0.10285261, 0.07173584,
#          0.09182224], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Chimpanzee'),
#   0.003923186,
#   array([0.01926133, 0.00400869, 0.06200906, 0.10446555, 0.07012418,
#          0.09784231], dtype=float32)),
#  (('FlyingFox', 'Horse', 'FlyingSqu'),
#   0.004624919,
#   array([0.01592046, 0.001826  , 0.11036311, 0.10836007, 0.06623387,
#          0.14245275], dtype=float32)),
#  (('FlyingFox', 'Horse', 'NineBande'),
#   0.0038552666,
#   array([0.02084072, 0.00661839, 0.05422683, 0.10032315, 0.07426367,
#          0.09285808], dtype=float32)),
#  (('FlyingFox', 'Horse', 'HairyArma'),
#   0.003362736,
#   array([0.01943312, 0.00546771, 0.05527789, 0.10072936, 0.07385771,
#          0.08576061], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Anteater'),
#   0.0044182064,
#   array([0.02115685, 0.00962985, 0.03179203, 0.09393213, 0.08065229,
#          0.11047756], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Sloth'),
#   0.0041599963,
#   array([0.01752955, 0.00707332, 0.03768892, 0.09217452, 0.08240955,
#          0.10235532], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Dugong'),
#   0.004140888,
#   array([0.01624456, 0.00327874, 0.00667705, 0.09701825, 0.07756708,
#          0.15576622], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Manatee'),
#   0.004300058,
#   array([0.01635509, 0.00809237, 0.00784487, 0.09518273, 0.07940199,
#          0.14217451], dtype=float32)),
#  (('FlyingFox', 'Horse', 'AfricanEl'),
#   0.0044014105,
#   array([0.0191554 , 0.00206823, 0.02053493, 0.1128756 , 0.06172586,
#          0.1477747 ], dtype=float32)),
#  (('FlyingFox', 'Horse', 'AsianElep'),
#   0.004205614,
#   array([0.01938104, 0.0018342 , 0.01521089, 0.1123185 , 0.06228182,
#          0.15837523], dtype=float32)),
#  (('FlyingFox', 'Horse', 'Aardvark'),
#   0.0043387944,
#   array([0.03479997, 0.00245042, 0.0847358 , 0.08815153, 0.08643215,
#          0.16388375], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Pangolin'),
#   0.0029139435,
#   array([0.0192634 , 0.0045528 , 0.05456201, 0.09649774, 0.04813915,
#          0.06188039], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Cat'),
#   0.00383075,
#   array([0.01871696, 0.00512256, 0.00886685, 0.10575134, 0.03900799,
#          0.14213726], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Dog'),
#   0.0039525074,
#   array([0.02093041, 0.00471338, 0.00916534, 0.11446117, 0.03057512,
#          0.18254392], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Llama'),
#   0.0036107143,
#   array([0.02072127, 0.00683782, 0.00441288, 0.09268725, 0.0519242 ,
#          0.12137009], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Pig'),
#   0.0035816384,
#   array([0.0195428 , 0.0180386 , 0.00460528, 0.09164534, 0.05296069,
#          0.16744286], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Cow'),
#   0.0048556617,
#   array([0.02158264, 0.00206937, 0.00739214, 0.09269756, 0.05191393,
#          0.1721746 ], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Hippo'),
#   0.0035450417,
#   array([0.02510018, 0.00703353, 0.00926181, 0.09334099, 0.05127414,
#          0.13316463], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'SpermWhale'),
#   0.0031088423,
#   array([0.02293802, 0.00748862, 0.02703529, 0.09168831, 0.05291793,
#          0.08624132], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'HumpbackW'),
#   0.0029741777,
#   array([0.02450197, 0.00555098, 0.02264488, 0.09122876, 0.05337526,
#          0.08724681], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Mole'),
#   0.0036612023,
#   array([0.01989915, 0.00864495, 0.03781822, 0.07710917, 0.0674618 ,
#          0.1793376 ], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'TreeShrew'),
#   0.004431534,
#   array([0.01802468, 0.00346792, 0.11564354, 0.0913648 , 0.05323986,
#          0.12149392], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'FlyingLem'),
#   0.003786751,
#   array([0.01853264, 0.00293449, 0.06803181, 0.09078673, 0.05381528,
#          0.09726283], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Galago'),
#   0.0037738597,
#   array([0.01899001, 0.00203423, 0.1085711 , 0.09698547, 0.04765543,
#          0.11131602], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'HowlerMon'),
#   0.0043615904,
#   array([0.01803889, 0.0034756 , 0.0783254 , 0.08870705, 0.05588656,
#          0.09398177], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Rhesus'),
#   0.004067392,
#   array([0.01483579, 0.00516074, 0.09772193, 0.08836047, 0.05623192,
#          0.11156254], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Orangutan'),
#   0.003948028,
#   array([0.01845086, 0.00295219, 0.08385469, 0.09222206, 0.0523869 ,
#          0.12504743], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Gorilla'),
#   0.0037066264,
#   array([0.03828572, 0.00280517, 0.08435247, 0.09424926, 0.05037144,
#          0.11008243], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Human'),
#   0.0039070346,
#   array([0.03164572, 0.00315165, 0.08755244, 0.09408217, 0.05053745,
#          0.10059255], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Chimpanzee'),
#   0.003702314,
#   array([0.03869507, 0.00280335, 0.0815808 , 0.09418774, 0.05043257,
#          0.10812031], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'FlyingSqu'),
#   0.0036563883,
#   array([0.01642732, 0.00293615, 0.12172958, 0.09486437, 0.04976041,
#          0.15594903], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'NineBande'),
#   0.0039342158,
#   array([0.02098431, 0.00303685, 0.06036212, 0.09721456, 0.04742832,
#          0.09596658], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'HairyArma'),
#   0.0034592596,
#   array([0.02055012, 0.00296385, 0.06458983, 0.09795629, 0.04669323,
#          0.08853335], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Anteater'),
#   0.004019483,
#   array([0.02358344, 0.00810688, 0.03341775, 0.09418261, 0.05043764,
#          0.11022705], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Sloth'),
#   0.0035150223,
#   array([0.01800664, 0.00607208, 0.04490554, 0.08915044, 0.05544483,
#          0.10537966], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Dugong'),
#   0.003575133,
#   array([0.01682865, 0.00515846, 0.02773405, 0.09667245, 0.04796585,
#          0.15611205], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Manatee'),
#   0.003604263,
#   array([0.0169491 , 0.00651763, 0.02606253, 0.0949446 , 0.0496807 ,
#          0.14241269], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'AfricanEl'),
#   0.003894751,
#   array([0.01806521, 0.00519252, 0.02329285, 0.09723723, 0.04740582,
#          0.16341352], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'AsianElep'),
#   0.0037025122,
#   array([0.01777146, 0.00496088, 0.01808241, 0.09661292, 0.04802489,
#          0.17408133], dtype=float32)),
#  (('FlyingFox', 'Rhino', 'Aardvark'),
#   0.0041163997,
#   array([0.01462248, 0.00427981, 0.10572135, 0.0941383 , 0.05048168,
#          0.15789631], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Cat'),
#   0.0037398187,
#   array([0.01744084, 0.04436288, 0.00517947, 0.10735443, 0.05106347,
#          0.14053413], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Dog'),
#   0.003719065,
#   array([0.01780928, 0.05125947, 0.00515813, 0.10177834, 0.0566138 ,
#          0.19522703], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Llama'),
#   0.003874742,
#   array([0.01866421, 0.04779785, 0.00371794, 0.10466644, 0.05373725,
#          0.10939037], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Pig'),
#   0.003907757,
#   array([0.0137467 , 0.05200955, 0.00416847, 0.09988733, 0.05849888,
#          0.15920028], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Cow'),
#   0.0046910327,
#   array([0.01421294, 0.05000877, 0.00381528, 0.09934692, 0.0590378 ,
#          0.16552481], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Hippo'),
#   0.0041094096,
#   array([0.01103663, 0.05586191, 0.00799241, 0.09342906, 0.06494387,
#          0.13307656], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'SpermWhale'),
#   0.003651514,
#   array([0.01881208, 0.05180711, 0.01849329, 0.09890465, 0.05947893,
#          0.07902636], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'HumpbackW'),
#   0.0034867988,
#   array([0.01899737, 0.04879724, 0.01547463, 0.10305671, 0.05534011,
#          0.0754218 ], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Mole'),
#   0.004238437,
#   array([0.0349571 , 0.05024876, 0.02990061, 0.10228822, 0.05610572,
#          0.15415445], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'TreeShrew'),
#   0.0042513795,
#   array([0.0116991 , 0.04628532, 0.10161082, 0.09871066, 0.0596724 ,
#          0.11414756], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'FlyingLem'),
#   0.0032584388,
#   array([0.0120663 , 0.05046082, 0.04601263, 0.09844951, 0.05993294,
#          0.08960013], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Galago'),
#   0.0035313452,
#   array([0.01105742, 0.04594987, 0.10303846, 0.10046282, 0.05792508,
#          0.10783856], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'HowlerMon'),
#   0.004437632,
#   array([0.01395072, 0.05286326, 0.02034011, 0.09919686, 0.05918748,
#          0.08349261], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Rhesus'),
#   0.004227237,
#   array([0.01157472, 0.05379418, 0.02923215, 0.0951575 , 0.06321813,
#          0.10476492], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Orangutan'),
#   0.0041901562,
#   array([0.0135536 , 0.04650025, 0.00505042, 0.09901552, 0.05936835,
#          0.11825351], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Gorilla'),
#   0.004166977,
#   array([0.01131254, 0.05113759, 0.00662229, 0.09431814, 0.06405612,
#          0.11001355], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Human'),
#   0.0042805606,
#   array([0.0100274 , 0.0526983 , 0.00826072, 0.09213381, 0.06623739,
#          0.10254101], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Chimpanzee'),
#   0.0041276114,
#   array([0.01161548, 0.05127689, 0.00627182, 0.09423617, 0.06413797,
#          0.10807186], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'FlyingSqu'),
#   0.0035761667,
#   array([0.01384978, 0.04054164, 0.09023005, 0.10882485, 0.04960262,
#          0.14198798], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'NineBande'),
#   0.0034164398,
#   array([0.01434126, 0.05037026, 0.04878677, 0.09766432, 0.06071629,
#          0.09551685], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'HairyArma'),
#   0.003282236,
#   array([0.01594697, 0.04876646, 0.01572986, 0.10063805, 0.05775039,
#          0.08585192], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Anteater'),
#   0.0041697673,
#   array([0.01607432, 0.05060955, 0.0238562 , 0.10011987, 0.05826702,
#          0.10428957], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Sloth'),
#   0.0037332843,
#   array([0.01498583, 0.05152381, 0.03134457, 0.09490853, 0.06346668,
#          0.09962119], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Dugong'),
#   0.0036335723,
#   array([0.01465282, 0.0457609 , 0.0060162 , 0.10504983, 0.05335566,
#          0.14773431], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Manatee'),
#   0.003734528,
#   array([0.01487715, 0.04679329, 0.00605134, 0.10427503, 0.05412687,
#          0.13308181], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'AfricanEl'),
#   0.0037151554,
#   array([0.01649197, 0.04197219, 0.01605106, 0.11084711, 0.04759601,
#          0.14980319], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'AsianElep'),
#   0.00356167,
#   array([0.01709154, 0.04056548, 0.01199535, 0.11349346, 0.04497554,
#          0.15720025], dtype=float32)),
#  (('FlyingFox', 'Pangolin', 'Aardvark'),
#   0.0037539003,
#   array([0.01081568, 0.05705317, 0.08900791, 0.08882618, 0.06954169,
#          0.16320902], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Dog'),
#   0.0038509325,
#   array([0.07817063, 0.0033929 , 0.00430018, 0.1675347 , 0.08035689,
#          0.1294703 ], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Llama'),
#   0.004073007,
#   array([0.01812991, 0.0063314 , 0.00347799, 0.09186836, 0.15602101,
#          0.12218905], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Pig'),
#   0.0040906323,
#   array([0.01774737, 0.00520848, 0.00315692, 0.09604659, 0.15184242,
#          0.16304122], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Cow'),
#   0.00469956,
#   array([0.01626702, 0.00554321, 0.0049094 , 0.08586591, 0.16202429,
#          0.1790072 ], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Hippo'),
#   0.0042506005,
#   array([0.01553899, 0.006527  , 0.0054041 , 0.09185549, 0.15603387,
#          0.13465029], dtype=float32)),
#  (('FlyingFox', 'Cat', 'SpermWhale'),
#   0.003911079,
#   array([0.02077692, 0.00535989, 0.00535489, 0.09657843, 0.15131055,
#          0.08135194], dtype=float32)),
#  (('FlyingFox', 'Cat', 'HumpbackW'),
#   0.003916145,
#   array([0.02067756, 0.00412684, 0.00361481, 0.10031152, 0.14757726,
#          0.07816582], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Mole'),
#   0.0038842494,
#   array([0.01184402, 0.0077895 , 0.03962945, 0.08101665, 0.1668747 ,
#          0.17542869], dtype=float32)),
#  (('FlyingFox', 'Cat', 'TreeShrew'),
#   0.004151983,
#   array([0.01272081, 0.0042243 , 0.11008137, 0.09686495, 0.15102401,
#          0.11599337], dtype=float32)),
#  (('FlyingFox', 'Cat', 'FlyingLem'),
#   0.0036766294,
#   array([0.0127579 , 0.00580229, 0.04054016, 0.08833006, 0.15955973,
#          0.09971968], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Galago'),
#   0.0035297861,
#   array([0.02308278, 0.00361995, 0.10871586, 0.0974797 , 0.15040924,
#          0.11082178], dtype=float32)),
#  (('FlyingFox', 'Cat', 'HowlerMon'),
#   0.0043816105,
#   array([0.01228779, 0.00754333, 0.06378421, 0.08687699, 0.16101305,
#          0.09581199], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Rhesus'),
#   0.0042310487,
#   array([0.01145541, 0.00647787, 0.07891272, 0.08816141, 0.15972841,
#          0.11176164], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Orangutan'),
#   0.0039811106,
#   array([0.01262334, 0.00574579, 0.07086304, 0.09717679, 0.15071215,
#          0.1200923 ], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Gorilla'),
#   0.0041167284,
#   array([0.01202552, 0.00682538, 0.06567826, 0.09899412, 0.14889474,
#          0.10533737], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Human'),
#   0.004185654,
#   array([0.00935235, 0.00715623, 0.0719054 , 0.09643825, 0.15145072,
#          0.0982364 ], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Chimpanzee'),
#   0.0040683206,
#   array([0.01249718, 0.0067791 , 0.06304181, 0.09798145, 0.14990745,
#          0.10432642], dtype=float32)),
#  (('FlyingFox', 'Cat', 'FlyingSqu'),
#   0.004538879,
#   array([0.01826604, 0.0039453 , 0.0292338 , 0.09514186, 0.15274723,
#          0.1556715 ], dtype=float32)),
#  (('FlyingFox', 'Cat', 'NineBande'),
#   0.0041218502,
#   array([0.01434633, 0.00539272, 0.03062162, 0.09613582, 0.1517532 ,
#          0.09704533], dtype=float32)),
#  (('FlyingFox', 'Cat', 'HairyArma'),
#   0.0033548374,
#   array([0.01455699, 0.00508905, 0.03982916, 0.09859112, 0.14929774,
#          0.08789857], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Anteater'),
#   0.0040187226,
#   array([0.04886283, 0.00604993, 0.02202982, 0.10093807, 0.14695066,
#          0.10347135], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Sloth'),
#   0.0041005937,
#   array([0.01144356, 0.00697658, 0.02768581, 0.09986809, 0.14802071,
#          0.09466165], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Dugong'),
#   0.0041572065,
#   array([0.01326407, 0.00290768, 0.00501995, 0.10124726, 0.14664148,
#          0.151537  ], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Manatee'),
#   0.0041581434,
#   array([0.0131753 , 0.00293242, 0.00497148, 0.09778849, 0.15010041,
#          0.1395686 ], dtype=float32)),
#  (('FlyingFox', 'Cat', 'AfricanEl'),
#   0.004183719,
#   array([0.01433012, 0.00249967, 0.01226727, 0.10366768, 0.14422098,
#          0.15698278], dtype=float32)),
#  (('FlyingFox', 'Cat', 'AsianElep'),
#   0.004166532,
#   array([0.01384846, 0.0024874 , 0.0091005 , 0.10326631, 0.14462236,
#          0.1674276 ], dtype=float32)),
#  (('FlyingFox', 'Cat', 'Aardvark'),
#   0.0046575028,
#   array([0.01056334, 0.00235504, 0.06674369, 0.09088495, 0.15700452,
#          0.16114998], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Llama'),
#   0.0044817915,
#   array([0.02142393, 0.00583543, 0.00367085, 0.08852541, 0.208481  ,
#          0.12553239], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Pig'),
#   0.00439507,
#   array([0.01876577, 0.00412657, 0.00345455, 0.09752715, 0.19947842,
#          0.16156057], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Cow'),
#   0.0053966353,
#   array([0.01433724, 0.00546744, 0.00584924, 0.07296323, 0.22404855,
#          0.19191478], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Hippo'),
#   0.004303901,
#   array([0.01809428, 0.00641623, 0.00651931, 0.08646001, 0.21054676,
#          0.14004648], dtype=float32)),
#  (('FlyingFox', 'Dog', 'SpermWhale'),
#   0.004042169,
#   array([0.01676009, 0.00531576, 0.00636378, 0.08023468, 0.2167736 ,
#          0.09769595], dtype=float32)),
#  (('FlyingFox', 'Dog', 'HumpbackW'),
#   0.0038877777,
#   array([0.01677309, 0.00478735, 0.00503969, 0.08477233, 0.21223472,
#          0.09370346], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Mole'),
#   0.0040960563,
#   array([0.01570071, 0.00526897, 0.03347947, 0.08325366, 0.21375376,
#          0.17319107], dtype=float32)),
#  (('FlyingFox', 'Dog', 'TreeShrew'),
#   0.00457645,
#   array([0.01591066, 0.00476734, 0.11937267, 0.08818083, 0.20882565,
#          0.12467828], dtype=float32)),
#  (('FlyingFox', 'Dog', 'FlyingLem'),
#   0.004086949,
#   array([0.01588156, 0.00223108, 0.02939403, 0.09451414, 0.20249164,
#          0.09353533], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Galago'),
#   0.003983562,
#   array([0.01475476, 0.00317186, 0.10429507, 0.09911533, 0.19789018,
#          0.10918608], dtype=float32)),
#  (('FlyingFox', 'Dog', 'HowlerMon'),
#   0.0042266366,
#   array([0.01382627, 0.00611243, 0.0684666 , 0.0861541 , 0.2108527 ,
#          0.09653494], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Rhesus'),
#   0.004187622,
#   array([0.01243853, 0.00420524, 0.08281435, 0.08619751, 0.21080929,
#          0.11372583], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Orangutan'),
#   0.0043013636,
#   array([0.01348609, 0.00437531, 0.05886365, 0.10331062, 0.19369467,
#          0.11395823], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Gorilla'),
#   0.004130287,
#   array([0.01383453, 0.0046524 , 0.05896276, 0.09885438, 0.19815114,
#          0.10547712], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Human'),
#   0.004186066,
#   array([0.01011241, 0.00500534, 0.06500364, 0.0947736 , 0.20223215,
#          0.0999011 ], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Chimpanzee'),
#   0.0040404038,
#   array([0.01384018, 0.00469639, 0.05722006, 0.09593412, 0.20107155,
#          0.10637382], dtype=float32)),
#  (('FlyingFox', 'Dog', 'FlyingSqu'),
#   0.0045161145,
#   array([0.06135083, 0.00341255, 0.00716562, 0.09557149, 0.20143421,
#          0.15524182], dtype=float32)),
#  (('FlyingFox', 'Dog', 'NineBande'),
#   0.004164858,
#   array([0.01877942, 0.00421627, 0.04111002, 0.10570949, 0.19129576,
#          0.08747223], dtype=float32)),
#  (('FlyingFox', 'Dog', 'HairyArma'),
#   0.0037226675,
#   array([0.01845633, 0.00381204, 0.04254795, 0.10921806, 0.18778712,
#          0.0772742 ], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Anteater'),
#   0.00474926,
#   array([0.01861952, 0.00547202, 0.02817242, 0.09958789, 0.19741757,
#          0.10482153], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Sloth'),
#   0.004199215,
#   array([0.01437924, 0.00521427, 0.03154337, 0.09678493, 0.20022067,
#          0.09774477], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Dugong'),
#   0.0042521562,
#   array([0.01360333, 0.00430593, 0.0060197 , 0.11046145, 0.18654369,
#          0.14232257], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Manatee'),
#   0.004245746,
#   array([0.01388596, 0.00432712, 0.0058293 , 0.10481005, 0.19219524,
#          0.13254677], dtype=float32)),
#  (('FlyingFox', 'Dog', 'AfricanEl'),
#   0.004327456,
#   array([0.01863309, 0.00385773, 0.01399665, 0.10763949, 0.1893657 ,
#          0.15301087], dtype=float32)),
#  (('FlyingFox', 'Dog', 'AsianElep'),
#   0.0041967314,
#   array([0.01770669, 0.0038525 , 0.01063341, 0.10767118, 0.189334  ,
#          0.16302261], dtype=float32)),
#  (('FlyingFox', 'Dog', 'Aardvark'),
#   0.005774936,
#   array([0.00477092, 0.00322212, 0.07748494, 0.09346662, 0.20353924,
#          0.15856805], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Pig'),
#   0.004612863,
#   array([0.06992673, 0.00173095, 0.00416233, 0.14775708, 0.06631245,
#          0.11133019], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Cow'),
#   0.0056702183,
#   array([0.01984456, 0.00156994, 0.0078513 , 0.1278367 , 0.08622147,
#          0.13703458], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Hippo'),
#   0.005679575,
#   array([0.06753295, 0.00151933, 0.00410888, 0.15505639, 0.0590273 ,
#          0.07145622], dtype=float32)),
#  (('FlyingFox', 'Llama', 'SpermWhale'),
#   0.004792638,
#   array([0.06577021, 0.00190506, 0.00582155, 0.15284893, 0.06122937,
#          0.02586088], dtype=float32)),
#  (('FlyingFox', 'Llama', 'HumpbackW'),
#   0.0049394327,
#   array([0.06817284, 0.00184722, 0.00386171, 0.15209281, 0.06198388,
#          0.02707069], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Mole'),
#   0.0043298453,
#   array([0.01168157, 0.00361426, 0.0410407 , 0.07343656, 0.14062625,
#          0.1830122 ], dtype=float32)),
#  (('FlyingFox', 'Llama', 'TreeShrew'),
#   0.00463855,
#   array([0.01704949, 0.00244208, 0.11431745, 0.09059774, 0.1234598 ,
#          0.12226107], dtype=float32)),
#  (('FlyingFox', 'Llama', 'FlyingLem'),
#   0.003762084,
#   array([0.0143678 , 0.00416409, 0.05946071, 0.08795676, 0.1261011 ,
#          0.10009301], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Galago'),
#   0.004149752,
#   array([0.01662769, 0.00182345, 0.10191053, 0.10321543, 0.11084141,
#          0.10508593], dtype=float32)),
#  (('FlyingFox', 'Llama', 'HowlerMon'),
#   0.0043306965,
#   array([0.01461841, 0.00339895, 0.06752986, 0.09046064, 0.12359693,
#          0.09222814], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Rhesus'),
#   0.004320866,
#   array([0.01152837, 0.00290805, 0.08328383, 0.09157188, 0.12248556,
#          0.10835079], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Orangutan'),
#   0.0041576084,
#   array([0.01476895, 0.00359999, 0.06912505, 0.09589145, 0.11816565,
#          0.12137773], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Gorilla'),
#   0.0040705535,
#   array([0.01216062, 0.00380698, 0.07471553, 0.09261824, 0.12143911,
#          0.11171357], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Human'),
#   0.004040613,
#   array([0.03121008, 0.00367142, 0.07690226, 0.08882094, 0.12523684,
#          0.10585418], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Chimpanzee'),
#   0.0040443353,
#   array([0.01248004, 0.00364966, 0.07172637, 0.09009776, 0.12395983,
#          0.11221059], dtype=float32)),
#  (('FlyingFox', 'Llama', 'FlyingSqu'),
#   0.00427825,
#   array([0.01602649, 0.00263711, 0.09736343, 0.10012831, 0.11392859,
#          0.15068476], dtype=float32)),
#  (('FlyingFox', 'Llama', 'NineBande'),
#   0.004320363,
#   array([0.01998261, 0.0030775 , 0.04422605, 0.09470323, 0.11935394,
#          0.09847794], dtype=float32)),
#  (('FlyingFox', 'Llama', 'HairyArma'),
#   0.0038259693,
#   array([0.01907521, 0.00348838, 0.04925567, 0.09561341, 0.11844371,
#          0.09087609], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Anteater'),
#   0.004747714,
#   array([0.01828183, 0.00344191, 0.02692727, 0.0941211 , 0.11993611,
#          0.11028856], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Sloth'),
#   0.004328239,
#   array([0.02079997, 0.00341155, 0.03186798, 0.09818407, 0.1158729 ,
#          0.09634563], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Dugong'),
#   0.00460896,
#   array([0.01364334, 0.00366701, 0.00753768, 0.1011368 , 0.11292008,
#          0.15164746], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Manatee'),
#   0.0046515837,
#   array([0.01455804, 0.00425734, 0.00773012, 0.10069269, 0.11336419,
#          0.13666426], dtype=float32)),
#  (('FlyingFox', 'Llama', 'AfricanEl'),
#   0.004383284,
#   array([0.04796446, 0.00265784, 0.01497081, 0.10292423, 0.11113261,
#          0.15772626], dtype=float32)),
#  (('FlyingFox', 'Llama', 'AsianElep'),
#   0.004218295,
#   array([0.04669475, 0.00259766, 0.01169101, 0.10270624, 0.11135059,
#          0.16798772], dtype=float32)),
#  (('FlyingFox', 'Llama', 'Aardvark'),
#   0.0047526285,
#   array([0.01287834, 0.00305566, 0.08577763, 0.08108889, 0.13297048,
#          0.17094792], dtype=float32)),
#  (('FlyingFox', 'Pig', 'Cow'),
#   0.005234658,
#   array([0.02132926, 0.00359094, 0.00498673, 0.12061559, 0.1384716 ,
#          0.14425573], dtype=float32)),
#  (('FlyingFox', 'Pig', 'Hippo'),
#   0.0045385677,
# ...
#   array([0.0045251 , 0.00441305, 0.06900562, 0.06386411, 0.17145316,
#          0.17822827], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'SpermWhale'),
#   0.004625803,
#   array([0.06781505, 0.00544027, 0.00145846, 0.15443826, 0.05547539,
#          0.00823174], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'HumpbackW'),
#   0.004590086,
#   array([0.07247711, 0.00573716, 0.00107555, 0.15368764, 0.05622317,
#          0.00954057], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Mole'),
#   0.0042337943,
#   array([0.01331302, 0.00777582, 0.03868408, 0.06215876, 0.1477358 ,
#          0.17331603], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'TreeShrew'),
#   0.005238924,
#   array([0.00786575, 0.00409799, 0.10238871, 0.0692227 , 0.14066175,
#          0.10567302], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'FlyingLem'),
#   0.003398165,
#   array([0.01105552, 0.00984145, 0.06490241, 0.07113197, 0.13875078,
#          0.08828852], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Galago'),
#   0.0037756644,
#   array([0.01149369, 0.00379665, 0.10726505, 0.08942374, 0.1204522 ,
#          0.11166445], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'HowlerMon'),
#   0.004294266,
#   array([0.01494986, 0.00674832, 0.06542443, 0.08274361, 0.12713355,
#          0.0900931 ], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Rhesus'),
#   0.004327535,
#   array([0.01105548, 0.00570701, 0.09237305, 0.0707038 , 0.13917929,
#          0.11321437], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Orangutan'),
#   0.004324035,
#   array([0.01453217, 0.00683322, 0.07284362, 0.08099686, 0.12888077,
#          0.11766595], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Gorilla'),
#   0.004282339,
#   array([0.01313456, 0.00648115, 0.07663922, 0.07968221, 0.13019584,
#          0.10227337], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Human'),
#   0.0043837926,
#   array([0.01054663, 0.00689199, 0.08152869, 0.07981961, 0.13005841,
#          0.09736407], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Chimpanzee'),
#   0.004218497,
#   array([0.01321009, 0.00681685, 0.07313187, 0.07967755, 0.1302005 ,
#          0.10179792], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'FlyingSqu'),
#   0.004455955,
#   array([0.01524173, 0.00827727, 0.00992734, 0.08358506, 0.12629189,
#          0.15145817], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'NineBande'),
#   0.0038144803,
#   array([0.01063809, 0.00906357, 0.05720383, 0.07460168, 0.13527866,
#          0.09221758], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'HairyArma'),
#   0.003555098,
#   array([0.01244708, 0.00770408, 0.05994395, 0.07707444, 0.13280465,
#          0.08466797], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Anteater'),
#   0.0046248953,
#   array([0.01388834, 0.00788793, 0.07901755, 0.0804639 , 0.1294139 ,
#          0.09814702], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Sloth'),
#   0.004135486,
#   array([0.03501046, 0.00858324, 0.04651151, 0.08257808, 0.12729913,
#          0.09440175], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Dugong'),
#   0.0040418017,
#   array([0.01080212, 0.00648269, 0.08697537, 0.07123204, 0.13865061,
#          0.14845169], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Manatee'),
#   0.0040491307,
#   array([0.01031831, 0.00591949, 0.08012664, 0.07292591, 0.13695548,
#          0.13530506], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'AfricanEl'),
#   0.0055841324,
#   array([0.0109368 , 0.00813028, 0.07098342, 0.09058657, 0.11928923,
#          0.13774073], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'AsianElep'),
#   0.004081172,
#   array([0.01076379, 0.00722249, 0.05854199, 0.08640328, 0.12347312,
#          0.1536595 ], dtype=float32)),
#  (('FreeTaile', 'Hippo', 'Aardvark'),
#   0.0042080316,
#   array([0.00451452, 0.00865187, 0.07963643, 0.06633751, 0.14355022,
#          0.17575121], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'HumpbackW'),
#   0.0027842857,
#   array([0.12166988, 0.0005937 , 0.00060789, 0.15270488, 0.00924079,
#          0.01015615], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Mole'),
#   0.0038947468,
#   array([0.01663526, 0.01929269, 0.03065578, 0.04974005, 0.10721856,
#          0.1857841 ], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'TreeShrew'),
#   0.005111075,
#   array([0.01006433, 0.00996395, 0.1089663 , 0.06273311, 0.09417555,
#          0.11217152], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'FlyingLem'),
#   0.0030834065,
#   array([0.0156488 , 0.00809181, 0.07380303, 0.06327178, 0.09363595,
#          0.09615766], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Galago'),
#   0.0031041713,
#   array([0.04044081, 0.00257399, 0.11786906, 0.07928666, 0.07761019,
#          0.12180373], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'HowlerMon'),
#   0.003988416,
#   array([0.04009964, 0.0155996 , 0.07096943, 0.08035541, 0.07654155,
#          0.09248172], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Rhesus'),
#   0.0035997487,
#   array([0.04080416, 0.01069247, 0.08746897, 0.07012859, 0.08677113,
#          0.11379009], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Orangutan'),
#   0.0036740853,
#   array([0.03983511, 0.01099511, 0.07321388, 0.07898284, 0.07791398,
#          0.11968063], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Gorilla'),
#   0.0035774768,
#   array([0.03496553, 0.01483255, 0.07838524, 0.07250582, 0.08439242,
#          0.10945318], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Human'),
#   0.0038605295,
#   array([0.02739832, 0.01199424, 0.08427398, 0.07511001, 0.08178724,
#          0.10207549], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Chimpanzee'),
#   0.0035375713,
#   array([0.03466979, 0.01553751, 0.0755551 , 0.07370876, 0.08318896,
#          0.10776938], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'FlyingSqu'),
#   0.0041743396,
#   array([0.01174822, 0.02332987, 0.00839888, 0.06790186, 0.08899973,
#          0.16715026], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'NineBande'),
#   0.0036749903,
#   array([0.00784237, 0.00842546, 0.06114535, 0.0654157 , 0.09148879,
#          0.10141163], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'HairyArma'),
#   0.0033555399,
#   array([0.01101443, 0.00635939, 0.05736869, 0.06899982, 0.08790077,
#          0.092747  ], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Anteater'),
#   0.0039193076,
#   array([0.01534546, 0.00722107, 0.08943263, 0.06647491, 0.09042825,
#          0.11214539], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Sloth'),
#   0.003655202,
#   array([0.03942307, 0.00668877, 0.04558055, 0.07127912, 0.08561981,
#          0.10570562], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Dugong'),
#   0.0034052453,
#   array([0.04360477, 0.00906687, 0.08154597, 0.07179905, 0.08509956,
#          0.14788423], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Manatee'),
#   0.003767637,
#   array([0.01778559, 0.01118583, 0.08005346, 0.07175612, 0.08514252,
#          0.13647568], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'AfricanEl'),
#   0.0038333756,
#   array([0.01731182, 0.01068734, 0.06846227, 0.07662857, 0.0802684 ,
#          0.15170227], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'AsianElep'),
#   0.0037225797,
#   array([0.01706401, 0.01038978, 0.05833538, 0.0769883 , 0.07990862,
#          0.16307724], dtype=float32)),
#  (('FreeTaile', 'SpermWhale', 'Aardvark'),
#   0.0043553766,
#   array([0.00445159, 0.00842669, 0.07695808, 0.06610453, 0.09079906,
#          0.17598447], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Mole'),
#   0.0039338088,
#   array([0.01567185, 0.01703105, 0.03449741, 0.05812936, 0.10026503,
#          0.17735532], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'TreeShrew'),
#   0.0051090084,
#   array([0.0093937 , 0.00695195, 0.108393  , 0.06291003, 0.09547325,
#          0.11199427], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'FlyingLem'),
#   0.0029308754,
#   array([0.01467163, 0.02365886, 0.07225075, 0.06194945, 0.09643563,
#          0.09748241], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Galago'),
#   0.0033797387,
#   array([0.01506893, 0.00217707, 0.11941362, 0.07753048, 0.08084092,
#          0.12356061], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'HowlerMon'),
#   0.0044949986,
#   array([0.01359329, 0.01784003, 0.06915181, 0.09577216, 0.06261166,
#          0.07706599], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Rhesus'),
#   0.003913322,
#   array([0.01613111, 0.00838617, 0.08900174, 0.07047466, 0.08789959,
#          0.1134437 ], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Orangutan'),
#   0.0040614884,
#   array([0.01503049, 0.00637993, 0.07591986, 0.07988715, 0.07848416,
#          0.11877599], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Gorilla'),
#   0.0038503106,
#   array([0.01339068, 0.0112947 , 0.07957288, 0.07304337, 0.08532935,
#          0.1089153 ], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Human'),
#   0.0039985785,
#   array([0.01005118, 0.0119893 , 0.08511279, 0.07320365, 0.08516901,
#          0.10398294], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Chimpanzee'),
#   0.0038071412,
#   array([0.01311688, 0.01182399, 0.07641505, 0.07369187, 0.08468056,
#          0.10778628], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'FlyingSqu'),
#   0.0042834124,
#   array([0.01228966, 0.01972012, 0.00856267, 0.06513514, 0.09324462,
#          0.16992058], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'NineBande'),
#   0.0035921948,
#   array([0.00731758, 0.02050281, 0.05881526, 0.06825855, 0.09011756,
#          0.09856534], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'HairyArma'),
#   0.0033433167,
#   array([0.0106004 , 0.01296039, 0.05577506, 0.07164891, 0.08672456,
#          0.09009586], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Anteater'),
#   0.003883941,
#   array([0.01429417, 0.01675567, 0.0841855 , 0.06888253, 0.089493  ,
#          0.10973502], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Sloth'),
#   0.0036381597,
#   array([0.03831597, 0.01284911, 0.04422827, 0.07376723, 0.08460518,
#          0.10321584], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Dugong'),
#   0.0038009281,
#   array([0.01735565, 0.0053134 , 0.08578049, 0.07413683, 0.08423541,
#          0.14554486], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Manatee'),
#   0.0039103627,
#   array([0.01779939, 0.00574834, 0.08198566, 0.07497852, 0.08339345,
#          0.13325119], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'AfricanEl'),
#   0.004038777,
#   array([0.01581588, 0.00595644, 0.07016683, 0.08142269, 0.0769488 ,
#          0.14690635], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'AsianElep'),
#   0.0039337156,
#   array([0.01600006, 0.00538059, 0.05958549, 0.08161262, 0.07675891,
#          0.15845124], dtype=float32)),
#  (('FreeTaile', 'HumpbackW', 'Aardvark'),
#   0.0041897795,
#   array([0.00469756, 0.019883  , 0.07532069, 0.06271749, 0.09566613,
#          0.17937694], dtype=float32)),
#  (('FreeTaile', 'Mole', 'TreeShrew'),
#   0.0054794867,
#   array([0.01816693, 0.0039212 , 0.1017013 , 0.07017057, 0.16529316,
#          0.10472429], dtype=float32)),
#  (('FreeTaile', 'Mole', 'FlyingLem'),
#   0.0038034464,
#   array([0.01545754, 0.04211696, 0.06926326, 0.06486409, 0.17060593,
#          0.09456281], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Galago'),
#   0.004197167,
#   array([0.01027381, 0.01742189, 0.12176658, 0.0759567 , 0.15950307,
#          0.12513508], dtype=float32)),
#  (('FreeTaile', 'Mole', 'HowlerMon'),
#   0.0069917394,
#   array([0.00903661, 0.03694655, 0.07411397, 0.08185507, 0.15360248,
#          0.09098177], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Rhesus'),
#   0.0048566256,
#   array([0.00988504, 0.02816684, 0.09197812, 0.06991626, 0.16554773,
#          0.11400262], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Orangutan'),
#   0.0050716675,
#   array([0.01113383, 0.02506582, 0.07249457, 0.07788809, 0.15757081,
#          0.1207758 ], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Gorilla'),
#   0.0051395455,
#   array([0.00998457, 0.02442406, 0.07029635, 0.07118688, 0.16427597,
#          0.1107731 ], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Human'),
#   0.005213012,
#   array([0.00678042, 0.02537319, 0.08218024, 0.07057977, 0.16488358,
#          0.10660873], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Chimpanzee'),
#   0.0051412303,
#   array([0.0105691 , 0.02446128, 0.06980596, 0.07399026, 0.16147062,
#          0.10748773], dtype=float32)),
#  (('FreeTaile', 'Mole', 'FlyingSqu'),
#   0.004770719,
#   array([0.01427152, 0.04511923, 0.00861588, 0.07460047, 0.16086002,
#          0.16044614], dtype=float32)),
#  (('FreeTaile', 'Mole', 'NineBande'),
#   0.0041813273,
#   array([0.01027685, 0.04074037, 0.0626349 , 0.06370847, 0.17176344,
#          0.1031215 ], dtype=float32)),
#  (('FreeTaile', 'Mole', 'HairyArma'),
#   0.004018054,
#   array([0.00998499, 0.04233807, 0.0669542 , 0.06586519, 0.16960338,
#          0.09588511], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Anteater'),
#   0.0045780684,
#   array([0.00808246, 0.02671308, 0.07267273, 0.06315008, 0.17232281,
#          0.11547532], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Sloth'),
#   0.0052613677,
#   array([0.0090461 , 0.03842513, 0.0135871 , 0.07167459, 0.1637879 ,
#          0.10530986], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Dugong'),
#   0.00429496,
#   array([0.02061136, 0.02733217, 0.07384245, 0.08228429, 0.15317315,
#          0.13739404], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Manatee'),
#   0.0042783134,
#   array([0.01956135, 0.02784429, 0.07275084, 0.08048236, 0.15497561,
#          0.12774502], dtype=float32)),
#  (('FreeTaile', 'Mole', 'AfricanEl'),
#   0.0063177245,
#   array([0.0255168 , 0.02824124, 0.02101615, 0.07842457, 0.15703413,
#          0.14990552], dtype=float32)),
#  (('FreeTaile', 'Mole', 'AsianElep'),
#   0.0061266194,
#   array([0.02401403, 0.02795055, 0.01569276, 0.07986517, 0.15559301,
#          0.16019924], dtype=float32)),
#  (('FreeTaile', 'Mole', 'Aardvark'),
#   0.0052232766,
#   array([0.00443635, 0.02213136, 0.07210778, 0.05986599, 0.17561391,
#          0.18223469], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'FlyingLem'),
#   0.005044926,
#   array([0.01721075, 0.0918581 , 0.01192141, 0.07790933, 0.09698103,
#          0.08150858], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Galago'),
#   0.005211125,
#   array([0.04555055, 0.07029371, 0.09676123, 0.10040334, 0.07448854,
#          0.10068426], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'HowlerMon'),
#   0.005684262,
#   array([0.02540028, 0.08295974, 0.04127729, 0.08928058, 0.08560826,
#          0.08355602], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Rhesus'),
#   0.0052264403,
#   array([0.05933937, 0.08386907, 0.04264514, 0.0858181 , 0.08907074,
#          0.09809389], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Orangutan'),
#   0.00599144,
#   array([0.06316959, 0.05848387, 0.02987799, 0.0893944 , 0.08549446,
#          0.1092668 ], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Gorilla'),
#   0.0059417356,
#   array([0.06422805, 0.0580587 , 0.02894053, 0.08886685, 0.08602198,
#          0.09308718], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Human'),
#   0.006099712,
#   array([0.05523095, 0.05927637, 0.03828305, 0.08832128, 0.08656751,
#          0.08886121], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Chimpanzee'),
#   0.0058736717,
#   array([0.06861793, 0.05848338, 0.02813031, 0.09172655, 0.08316255,
#          0.08974741], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'FlyingSqu'),
#   0.005560926,
#   array([0.02083689, 0.07296393, 0.00640232, 0.10002133, 0.07487036,
#          0.13502002], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'NineBande'),
#   0.005417319,
#   array([0.00508051, 0.09777547, 0.03535806, 0.074527  , 0.10036483,
#          0.09229229], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'HairyArma'),
#   0.0050866157,
#   array([0.005899  , 0.09529207, 0.0295142 , 0.07539313, 0.09949828,
#          0.08634979], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Anteater'),
#   0.0054491367,
#   array([0.00702721, 0.09375004, 0.05107626, 0.07576165, 0.09912958,
#          0.102851  ], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Sloth'),
#   0.006276383,
#   array([0.00614714, 0.09410979, 0.00651353, 0.07772851, 0.09716191,
#          0.09925264], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Dugong'),
#   0.005355948,
#   array([0.00793881, 0.09118608, 0.04799469, 0.07968913, 0.09520068,
#          0.13999   ], dtype=float32)),
#  (('FreeTaile', 'TreeShrew', 'Manatee'),
#   0.0055919173,
#   array([0.00681319, 0.08912633, 0.0421089 , 0.08111104, 0.09377842,
#          0.12711614], dtype=float32)),
#  ...]

# %%
#lengths = [np.exp(p[:3]) for p in params]
#lengths = [np.exp(p[:3]) == np.exp(p[:3]).max() for p in params]
#lengths = [np.exp(p[:3])/np.exp(p[:3]).sum() for p in params]
#h = np.array([-(p*np.log(p)).sum() for p in lengths])
#lengths = np.diag(1/(h + 1)) @ lengths
lengths = [np.array([p.numpy() for p in param[4:7]]) for param in params]
tree = pulsar_tree(triples, lengths, losses, verbose=False)
print(tree.ascii_art())
# Out:
#                               /-Galago
#                     /--------|
#                    |          \-TreeShrew
#                    |
#                    |                    /-Orangutan
#           /--------|          /--------|
#          |         |         |         |          /-Human
#          |         |         |          \--------|
#          |         |         |                   |          /-Chimpanzee
#          |          \--------|                    \--------|
#          |                   |                              \-Gorilla
#          |                   |
#          |                   |          /-HowlerMon
#          |                    \--------|
#          |                              \-Rhesus
#          |
#          |                                        /-Llama
#          |                              /--------|
#          |                             |          \-Pig
#          |                    /--------|
#          |                   |         |          /-Cow
#          |                   |          \--------|
#          |                   |                   |          /-Hippo
#          |                   |                    \--------|
#          |                   |                             |          /-HumpbackW
# ---------|                   |                              \--------|
#          |                   |                                        \-SpermWhale
#          |                   |
#          |                   |                                        /-FlyingFox
#          |                   |                              /--------|
#          |          /--------|                             |          \-LeafNose
#          |         |         |                    /--------|
#          |         |         |                   |         |          /-TombBat
#          |         |         |                   |          \--------|
#          |         |         |                   |                   |          /-FreeTaile
#          |         |         |                   |                    \--------|
#          |         |         |          /--------|                              \-LittleBro
#          |         |         |         |         |
#          |         |         |         |         |                    /-Pangolin
#          |         |         |         |         |          /--------|
#          |         |         |         |         |         |         |          /-Horse
#          |         |          \--------|          \--------|          \--------|
#          |         |                   |                   |                    \-Rhino
#          |         |                   |                   |
#          |         |                   |                    \-Mole
#           \--------|                   |
#                    |                   |          /-FlyingSqu
#                    |                    \--------|
#                    |                             |          /-Cat
#                    |                              \--------|
#                    |                                        \-Dog
#                    |
#                    |                              /-Aardvark
#                    |                    /--------|
#                    |                   |         |          /-AfricanEl
#                    |                   |          \--------|
#                    |          /--------|                    \-AsianElep
#                    |         |         |
#                    |         |         |          /-Dugong
#                    |         |          \--------|
#                     \--------|                    \-Manatee
#                              |
#                              |                    /-Anteater
#                              |          /--------|
#                              |         |          \-Sloth
#                               \--------|
#                                        |          /-FlyingLem
#                                         \--------|
#                                                  |          /-HairyArma
#                                                   \--------|
#                                                             \-NineBande

# %%
lengths = [np.exp(p[:3]) for p in params]
#lengths = [np.exp(p[:3]) == np.exp(p[:3]).max() for p in params]
lengths = [np.exp(p[:3])/np.exp(p[:6]).sum() for p in params]
#h = np.array([-(p*np.log(p)).sum() for p in lengths])
#lengths = np.diag(1/(h + 1)) @ lengths
tree = pulsar_tree(triples, lengths, losses, verbose=False)
print(tree.ascii_art())
# Out:
#                               /-HowlerMon
#                     /--------|
#                    |          \-Sloth
#           /--------|
#          |         |          /-Pangolin
#          |          \--------|
#          |                   |          /-FlyingLem
#          |                    \--------|
#          |                              \-Rhesus
#          |
#          |                                        /-Orangutan
# ---------|                              /--------|
#          |                             |         |          /-Chimpanzee
#          |                    /--------|          \--------|
#          |                   |         |                    \-Human
#          |          /--------|         |
#          |         |         |          \-Rhino
#          |         |         |
#          |         |          \-Horse
#           \--------|
#                    |                    /-Llama
#                    |          /--------|
#                    |         |          \-SpermWhale
#                     \--------|
#                              |          /-HumpbackW
#                               \--------|
#                                        |          /-Gorilla
#                                         \--------|
#                                                   \-HairyArma

# %%
sorted(list(zip(h, (n for n, _ in triples))))
# Out:
# [(0.16873865, ('FlyingLem', 'Human', 'Chimpanzee')),
#  (0.18088952, ('SpermWhale', 'Human', 'Chimpanzee')),
#  (0.29110888, ('Rhino', 'Orangutan', 'Gorilla')),
#  (0.3259487, ('Rhino', 'Orangutan', 'Human')),
#  (0.33282077, ('HowlerMon', 'Human', 'Chimpanzee')),
#  (0.3472516, ('Rhesus', 'Human', 'Chimpanzee')),
#  (0.4210934, ('HowlerMon', 'Orangutan', 'Human')),
#  (0.48457676, ('HowlerMon', 'Orangutan', 'Chimpanzee')),
#  (0.5511679, ('Rhesus', 'Orangutan', 'Human')),
#  (0.630245, ('HowlerMon', 'Orangutan', 'Gorilla')),
#  (0.6435783, ('Llama', 'SpermWhale', 'Rhesus')),
#  (0.6758433, ('HumpbackW', 'Gorilla', 'Human')),
#  (0.6785302, ('FlyingLem', 'Gorilla', 'Human')),
#  (0.7086155, ('SpermWhale', 'Gorilla', 'Human')),
#  (0.7768129, ('Llama', 'SpermWhale', 'HairyArma')),
#  (0.7871436, ('Horse', 'Gorilla', 'Human')),
#  (0.7897128, ('HowlerMon', 'Gorilla', 'Human')),
#  (0.83272696, ('Horse', 'Rhino', 'HowlerMon')),
#  (0.85429287, ('Llama', 'HumpbackW', 'HowlerMon')),
#  (0.8665911, ('Llama', 'HowlerMon', 'Chimpanzee')),
#  (0.8684721, ('Rhesus', 'Orangutan', 'HairyArma')),
#  (0.87676996, ('Rhesus', 'Gorilla', 'HairyArma')),
#  (0.8805225, ('Rhesus', 'Chimpanzee', 'HairyArma')),
#  (0.8876042, ('Orangutan', 'Human', 'Chimpanzee')),
#  (0.8934127, ('Llama', 'HowlerMon', 'Human')),
#  (0.89584297, ('Llama', 'HumpbackW', 'HairyArma')),
#  (0.89910877, ('Llama', 'HowlerMon', 'Gorilla')),
#  (0.90406024, ('HumpbackW', 'HowlerMon', 'Gorilla')),
#  (0.91422, ('Llama', 'HumpbackW', 'Rhesus')),
#  (0.9144072, ('Llama', 'HumpbackW', 'Sloth')),
#  (0.9161433, ('Llama', 'SpermWhale', 'Sloth')),
#  (0.9165726, ('Rhesus', 'Gorilla', 'Sloth')),
#  (0.91697544, ('Rhesus', 'Chimpanzee', 'Sloth')),
#  (0.92411315, ('HumpbackW', 'HowlerMon', 'Rhesus')),
#  (0.9259957, ('Pangolin', 'Rhesus', 'Orangutan')),
#  (0.9267282, ('Rhino', 'Rhesus', 'Human')),
#  (0.9275114, ('Llama', 'HumpbackW', 'Human')),
#  (0.9372313, ('Orangutan', 'Gorilla', 'Human')),
#  (0.9389597, ('Llama', 'Rhesus', 'Orangutan')),
#  (0.9404252, ('Llama', 'SpermWhale', 'Human')),
#  (0.94811153, ('Llama', 'HumpbackW', 'Chimpanzee')),
#  (0.9493412, ('Llama', 'HumpbackW', 'Gorilla')),
#  (0.95104635, ('Pangolin', 'Rhesus', 'Chimpanzee')),
#  (0.95331043, ('Pangolin', 'Rhesus', 'Gorilla')),
#  (0.9540738, ('Llama', 'HumpbackW', 'Orangutan')),
#  (0.9580381, ('Llama', 'Rhesus', 'Chimpanzee')),
#  (0.9584543, ('HowlerMon', 'Gorilla', 'HairyArma')),
#  (0.96295637, ('Llama', 'Rhesus', 'Gorilla')),
#  (0.9637498, ('Rhesus', 'Human', 'HairyArma')),
#  (0.9658036, ('Llama', 'SpermWhale', 'Chimpanzee')),
#  (0.96781945, ('HowlerMon', 'Chimpanzee', 'HairyArma')),
#  (0.9715598, ('Llama', 'HumpbackW', 'FlyingLem')),
#  (0.9717761, ('Rhesus', 'Orangutan', 'Sloth')),
#  (0.97293305, ('HowlerMon', 'Gorilla', 'Sloth')),
#  (0.9734028, ('FlyingLem', 'Rhesus', 'Gorilla')),
#  (0.9761912, ('FlyingLem', 'Rhesus', 'Chimpanzee')),
#  (0.9800013, ('HumpbackW', 'Orangutan', 'Human')),
#  (0.9802297, ('Llama', 'Orangutan', 'Gorilla')),
#  (0.98260784, ('Rhesus', 'Human', 'Sloth')),
#  (0.9830219, ('Pangolin', 'HowlerMon', 'Gorilla')),
#  (0.9856719, ('Llama', 'SpermWhale', 'Gorilla')),
#  (0.9865366, ('SpermWhale', 'HowlerMon', 'Rhesus')),
#  (0.9869932, ('FlyingLem', 'Rhesus', 'Orangutan')),
#  (0.98725706, ('HowlerMon', 'Chimpanzee', 'Sloth')),
#  (0.9879595, ('Pangolin', 'HowlerMon', 'Chimpanzee')),
#  (0.98973644, ('SpermWhale', 'Orangutan', 'Gorilla')),
#  (0.9903233, ('HumpbackW', 'Orangutan', 'Gorilla')),
#  (0.9924182, ('Pangolin', 'Rhesus', 'Human')),
#  (0.9929405, ('Horse', 'Llama', 'HowlerMon')),
#  (0.99406064, ('Pangolin', 'Orangutan', 'Gorilla')),
#  (0.9950074, ('Orangutan', 'Gorilla', 'HairyArma')),
#  (0.9954408, ('SpermWhale', 'Orangutan', 'Human')),
#  (0.9967108, ('SpermWhale', 'HowlerMon', 'Gorilla')),
#  (0.99719423, ('HowlerMon', 'Rhesus', 'HairyArma')),
#  (0.9975579, ('SpermWhale', 'HowlerMon', 'Chimpanzee')),
#  (0.9982066, ('Rhino', 'Orangutan', 'Chimpanzee')),
#  (1.0018874, ('Llama', 'Orangutan', 'Human')),
#  (1.0020767, ('Orangutan', 'Gorilla', 'Sloth')),
#  (1.0025921, ('Pangolin', 'HowlerMon', 'Orangutan')),
#  (1.0048393, ('Llama', 'Rhesus', 'Human')),
#  (1.0059365, ('Rhino', 'Rhesus', 'Chimpanzee')),
#  (1.0060812, ('Horse', 'Human', 'Chimpanzee')),
#  (1.0063725, ('Horse', 'Orangutan', 'Gorilla')),
#  (1.0072994, ('Llama', 'SpermWhale', 'Orangutan')),
#  (1.0074838, ('FlyingLem', 'Orangutan', 'Gorilla')),
#  (1.0089079, ('Llama', 'Human', 'Chimpanzee')),
#  (1.0101354, ('HowlerMon', 'Human', 'HairyArma')),
#  (1.010592, ('Human', 'Chimpanzee', 'HairyArma')),
#  (1.01135, ('Rhino', 'Rhesus', 'Gorilla')),
#  (1.0115253, ('Horse', 'SpermWhale', 'HowlerMon')),
#  (1.0142525, ('Orangutan', 'Chimpanzee', 'Sloth')),
#  (1.014528, ('Pangolin', 'Orangutan', 'Human')),
#  (1.0145552, ('Pangolin', 'Human', 'Chimpanzee')),
#  (1.0147517, ('Pangolin', 'HowlerMon', 'Human')),
#  (1.0147891, ('SpermWhale', 'Rhesus', 'Human')),
#  (1.0151939, ('HumpbackW', 'Rhesus', 'Chimpanzee')),
#  (1.0156627, ('HumpbackW', 'Rhesus', 'Human')),
#  (1.0166405, ('FlyingLem', 'Orangutan', 'Chimpanzee')),
#  (1.0170251, ('SpermWhale', 'Rhesus', 'Chimpanzee')),
#  (1.0175267, ('SpermWhale', 'Rhesus', 'Gorilla')),
#  (1.0178037, ('HumpbackW', 'Gorilla', 'Chimpanzee')),
#  (1.0181352, ('HumpbackW', 'Human', 'Chimpanzee')),
#  (1.0181684, ('Llama', 'Gorilla', 'Chimpanzee')),
#  (1.0183703, ('Rhino', 'Gorilla', 'Human')),
#  (1.0184362, ('HumpbackW', 'Rhesus', 'Gorilla')),
#  (1.0187774, ('Gorilla', 'Human', 'HairyArma')),
#  (1.0192965, ('Llama', 'Gorilla', 'Human')),
#  (1.0193188, ('SpermWhale', 'Gorilla', 'Chimpanzee')),
#  (1.0197189, ('Horse', 'Llama', 'Rhesus')),
#  (1.0199862, ('Human', 'Chimpanzee', 'Sloth')),
#  (1.0201385, ('FlyingLem', 'Rhesus', 'Human')),
#  (1.0202954, ('HowlerMon', 'Human', 'Sloth')),
#  (1.0203681, ('Horse', 'Rhesus', 'Chimpanzee')),
#  (1.0207946, ('Horse', 'HumpbackW', 'HowlerMon')),
#  (1.0208602, ('SpermWhale', 'HumpbackW', 'FlyingLem')),
#  (1.0210168, ('Gorilla', 'Chimpanzee', 'HairyArma')),
#  (1.0211122, ('Pangolin', 'Gorilla', 'Human')),
#  (1.0212568, ('Horse', 'Orangutan', 'Chimpanzee')),
#  (1.0217164, ('Gorilla', 'Human', 'Sloth')),
#  (1.0220749, ('Rhino', 'Gorilla', 'Chimpanzee')),
#  (1.022295, ('HowlerMon', 'Orangutan', 'Sloth')),
#  (1.022385, ('SpermWhale', 'HowlerMon', 'Human')),
#  (1.0224302, ('Gorilla', 'Chimpanzee', 'Sloth')),
#  (1.0226743, ('Horse', 'Rhesus', 'Human')),
#  (1.022833, ('Pangolin', 'Gorilla', 'Chimpanzee')),
#  (1.0233335, ('Rhino', 'Rhesus', 'Orangutan')),
#  (1.024761, ('Orangutan', 'Human', 'HairyArma')),
#  (1.0254195, ('Horse', 'Pangolin', 'Rhesus')),
#  (1.0258193, ('Orangutan', 'Chimpanzee', 'HairyArma')),
#  (1.0259473, ('SpermWhale', 'Orangutan', 'Chimpanzee')),
#  (1.0259821, ('HumpbackW', 'Orangutan', 'Chimpanzee')),
#  (1.026154, ('Rhino', 'Human', 'Chimpanzee')),
#  (1.0262578, ('Pangolin', 'HowlerMon', 'Rhesus')),
#  (1.0264382, ('Llama', 'Orangutan', 'Chimpanzee')),
#  (1.0267036, ('Llama', 'Rhesus', 'Sloth')),
#  (1.0279574, ('FlyingLem', 'Gorilla', 'Chimpanzee')),
#  (1.0280149, ('Pangolin', 'Orangutan', 'Chimpanzee')),
#  (1.029525, ('Horse', 'Gorilla', 'Chimpanzee')),
#  (1.0298886, ('Horse', 'Rhesus', 'Orangutan')),
#  (1.0321356, ('Pangolin', 'SpermWhale', 'HumpbackW')),
#  (1.0338973, ('SpermWhale', 'HumpbackW', 'Gorilla')),
#  (1.0340037, ('FlyingLem', 'HowlerMon', 'Gorilla')),
#  (1.0340917, ('SpermWhale', 'HumpbackW', 'Rhesus')),
#  (1.0342451, ('SpermWhale', 'HumpbackW', 'HairyArma')),
#  (1.0351999, ('Llama', 'HowlerMon', 'Rhesus')),
#  (1.0360274, ('SpermWhale', 'HumpbackW', 'Orangutan')),
#  (1.0361551, ('SpermWhale', 'HumpbackW', 'Human')),
#  (1.0365933, ('SpermWhale', 'HumpbackW', 'Chimpanzee')),
#  (1.0366726, ('Horse', 'SpermWhale', 'HumpbackW')),
#  (1.0376515, ('Rhino', 'SpermWhale', 'HumpbackW')),
#  (1.0402794, ('HumpbackW', 'HowlerMon', 'Chimpanzee')),
#  (1.0427345, ('FlyingLem', 'HowlerMon', 'Chimpanzee')),
#  (1.0443332, ('Horse', 'Llama', 'HumpbackW')),
#  (1.0446775, ('Horse', 'SpermWhale', 'Gorilla')),
#  (1.0469122, ('SpermWhale', 'HumpbackW', 'HowlerMon')),
#  (1.0473294, ('HowlerMon', 'HairyArma', 'Sloth')),
#  (1.0473464, ('Gorilla', 'Human', 'Chimpanzee')),
#  (1.0485563, ('Rhino', 'HowlerMon', 'Gorilla')),
#  (1.0493076, ('SpermWhale', 'HumpbackW', 'Sloth')),
#  (1.0505487, ('Llama', 'SpermWhale', 'HowlerMon')),
#  (1.050863, ('HowlerMon', 'Rhesus', 'Sloth')),
#  (1.050923, ('Llama', 'Orangutan', 'Sloth')),
#  (1.0512766, ('Pangolin', 'Llama', 'Rhesus')),
#  (1.0542365, ('Rhino', 'Llama', 'HumpbackW')),
#  (1.0546186, ('SpermWhale', 'Rhesus', 'Orangutan')),
#  (1.0550501, ('Rhino', 'HowlerMon', 'Chimpanzee')),
#  (1.0552102, ('HumpbackW', 'Rhesus', 'Orangutan')),
#  (1.0555856, ('Horse', 'SpermWhale', 'Chimpanzee')),
#  (1.0566847, ('HumpbackW', 'HowlerMon', 'Human')),
#  (1.0576179, ('Horse', 'HumpbackW', 'Gorilla')),
#  (1.058387, ('Rhino', 'Rhesus', 'HairyArma')),
#  (1.0588706, ('Pangolin', 'FlyingLem', 'HowlerMon')),
#  (1.0603036, ('Horse', 'SpermWhale', 'Human')),
#  (1.0603775, ('HumpbackW', 'FlyingLem', 'HowlerMon')),
#  (1.0630033, ('Horse', 'FlyingLem', 'HowlerMon')),
#  (1.0630553, ('Horse', 'Pangolin', 'HumpbackW')),
#  (1.0635498, ('Horse', 'HowlerMon', 'Rhesus')),
#  (1.0639493, ('Horse', 'HowlerMon', 'HairyArma')),
#  (1.0639663, ('Horse', 'Rhesus', 'Gorilla')),
#  (1.0646641, ('Horse', 'Rhino', 'HairyArma')),
#  (1.0646968, ('HowlerMon', 'Orangutan', 'HairyArma')),
#  (1.0656183, ('FlyingLem', 'HowlerMon', 'Human')),
#  (1.0656483, ('Llama', 'SpermWhale', 'HumpbackW')),
#  (1.0668428, ('Rhino', 'Llama', 'Human')),
#  (1.0670406, ('SpermWhale', 'HairyArma', 'Sloth')),
#  (1.0674576, ('Rhesus', 'Orangutan', 'Gorilla')),
#  (1.067474, ('Pangolin', 'HumpbackW', 'FlyingLem')),
#  (1.0675466, ('Rhino', 'HumpbackW', 'HairyArma')),
#  (1.0676918, ('Horse', 'Pangolin', 'SpermWhale')),
#  (1.0677844, ('HowlerMon', 'Gorilla', 'Chimpanzee')),
#  (1.0687548, ('SpermWhale', 'HowlerMon', 'Orangutan')),
#  (1.0691649, ('Horse', 'Rhino', 'Pangolin')),
#  (1.0696336, ('Horse', 'SpermWhale', 'Rhesus')),
#  (1.0697742, ('Horse', 'SpermWhale', 'Orangutan')),
#  (1.0699676, ('Pangolin', 'FlyingLem', 'Orangutan')),
#  (1.0699836, ('FlyingLem', 'HowlerMon', 'Rhesus')),
#  (1.0699899, ('Pangolin', 'FlyingLem', 'Gorilla')),
#  (1.0701524, ('Rhino', 'Llama', 'Chimpanzee')),
#  (1.0706179, ('Rhino', 'HowlerMon', 'Rhesus')),
#  (1.0707599, ('Rhino', 'HowlerMon', 'Human')),
#  (1.0708168, ('HumpbackW', 'HowlerMon', 'HairyArma')),
#  (1.0709536, ('Horse', 'HowlerMon', 'Chimpanzee')),
#  (1.0713344, ('Horse', 'HowlerMon', 'Gorilla')),
#  (1.0714133, ('Llama', 'HowlerMon', 'Orangutan')),
#  (1.0715032, ('Horse', 'HumpbackW', 'Chimpanzee')),
#  (1.071707, ('Rhino', 'HowlerMon', 'Orangutan')),
#  (1.071917, ('Llama', 'HowlerMon', 'HairyArma')),
#  (1.0719392, ('Rhino', 'Llama', 'Orangutan')),
#  (1.0720481, ('Horse', 'Rhesus', 'HairyArma')),
#  (1.0731649, ('Horse', 'HumpbackW', 'Human')),
#  (1.0732441, ('Rhino', 'Llama', 'Rhesus')),
#  (1.0733317, ('Horse', 'HowlerMon', 'Human')),
#  (1.0735416, ('Rhino', 'Llama', 'Gorilla')),
#  (1.0736516, ('Horse', 'HowlerMon', 'Orangutan')),
#  (1.0738989, ('HumpbackW', 'HowlerMon', 'Orangutan')),
#  (1.0741794, ('Horse', 'Rhino', 'Sloth')),
#  (1.0751317, ('Pangolin', 'FlyingLem', 'Chimpanzee')),
#  (1.0755836, ('Horse', 'Gorilla', 'HairyArma')),
#  (1.0757077, ('Pangolin', 'Llama', 'SpermWhale')),
#  (1.0767448, ('FlyingLem', 'HairyArma', 'Sloth')),
#  (1.0773162, ('Rhino', 'Gorilla', 'HairyArma')),
#  (1.0776052, ('Rhesus', 'Gorilla', 'Human')),
#  (1.0776397, ('Horse', 'Pangolin', 'HairyArma')),
#  (1.0776466, ('Horse', 'Orangutan', 'Human')),
#  (1.0777566, ('Rhesus', 'Gorilla', 'Chimpanzee')),
#  (1.0779195, ('Rhino', 'Orangutan', 'HairyArma')),
#  (1.0779562, ('Pangolin', 'HairyArma', 'Sloth')),
#  (1.078075, ('Llama', 'Rhesus', 'HairyArma')),
#  (1.0783505, ('Pangolin', 'FlyingLem', 'Sloth')),
#  (1.0786128, ('FlyingLem', 'HowlerMon', 'Orangutan')),
#  (1.0786622, ('Llama', 'SpermWhale', 'FlyingLem')),
#  (1.0786939, ('Rhino', 'Pangolin', 'FlyingLem')),
#  (1.0789968, ('Pangolin', 'FlyingLem', 'Human')),
#  (1.0790912, ('Horse', 'HumpbackW', 'Rhesus')),
#  (1.0791557, ('Pangolin', 'SpermWhale', 'FlyingLem')),
#  (1.0796762, ('Horse', 'Gorilla', 'Sloth')),
#  (1.0802481, ('Rhino', 'Chimpanzee', 'HairyArma')),
#  (1.0806782, ('SpermWhale', 'FlyingLem', 'HowlerMon')),
#  (1.0806985, ('Pangolin', 'HumpbackW', 'Sloth')),
#  (1.0812081, ('Llama', 'Human', 'HairyArma')),
#  (1.0812596, ('HumpbackW', 'HowlerMon', 'Sloth')),
#  (1.0816506, ('Horse', 'Rhino', 'HumpbackW')),
#  (1.082077, ('Rhesus', 'HairyArma', 'Sloth')),
#  (1.0820793, ('Horse', 'HumpbackW', 'Orangutan')),
#  (1.08246, ('Llama', 'Chimpanzee', 'Sloth')),
#  (1.0827812, ('Llama', 'Chimpanzee', 'HairyArma')),
#  (1.083279, ('Llama', 'Gorilla', 'HairyArma')),
#  (1.0834429, ('Llama', 'Human', 'Sloth')),
#  (1.0835057, ('Horse', 'Pangolin', 'Sloth')),
#  (1.0836208, ('Horse', 'HowlerMon', 'Sloth')),
#  (1.0836278, ('Rhino', 'SpermWhale', 'HowlerMon')),
#  (1.0836561, ('Llama', 'FlyingLem', 'HowlerMon')),
#  (1.0836861, ('Horse', 'Rhino', 'Llama')),
#  (1.0845271, ('Human', 'HairyArma', 'Sloth')),
#  (1.0845641, ('SpermWhale', 'FlyingLem', 'Sloth')),
#  (1.084846, ('Gorilla', 'HairyArma', 'Sloth')),
#  (1.0850819, ('Rhino', 'HowlerMon', 'HairyArma')),
#  (1.08511, ('Rhesus', 'Orangutan', 'Chimpanzee')),
#  (1.0851845, ('Orangutan', 'HairyArma', 'Sloth')),
#  (1.0853311, ('Horse', 'SpermWhale', 'HairyArma')),
#  (1.0854613, ('Pangolin', 'Llama', 'HumpbackW')),
#  (1.0854626, ('Pangolin', 'HumpbackW', 'HairyArma')),
#  (1.0854833, ('Pangolin', 'SpermWhale', 'Sloth')),
#  (1.0856055, ('Pangolin', 'FlyingLem', 'HairyArma')),
#  (1.0857472, ('Chimpanzee', 'HairyArma', 'Sloth')),
#  (1.0857637, ('Horse', 'HumpbackW', 'HairyArma')),
#  (1.0861495, ('Llama', 'FlyingLem', 'Gorilla')),
#  (1.0863146, ('SpermWhale', 'HowlerMon', 'Sloth')),
#  (1.0863781, ('Rhino', 'Pangolin', 'Sloth')),
#  (1.0865282, ('Horse', 'Rhino', 'FlyingLem')),
#  (1.0866647, ('Pangolin', 'FlyingLem', 'Rhesus')),
#  (1.0868709, ('FlyingLem', 'Orangutan', 'Sloth')),
#  (1.0868852, ('Horse', 'Llama', 'SpermWhale')),
#  (1.0869261, ('Horse', 'Rhino', 'SpermWhale')),
#  (1.0874281, ('Pangolin', 'SpermWhale', 'HairyArma')),
#  (1.0875195, ('FlyingLem', 'Rhesus', 'Sloth')),
#  (1.0875298, ('FlyingLem', 'Human', 'Sloth')),
#  (1.0875837, ('Horse', 'SpermWhale', 'FlyingLem')),
#  (1.0877298, ('Horse', 'FlyingLem', 'Gorilla')),
#  (1.0877848, ('Horse', 'Chimpanzee', 'Sloth')),
#  (1.0880797, ('FlyingLem', 'Chimpanzee', 'Sloth')),
#  (1.0884856, ('HumpbackW', 'Human', 'HairyArma')),
#  (1.0886319, ('Pangolin', 'Rhesus', 'HairyArma')),
#  (1.0889176, ('Llama', 'FlyingLem', 'Chimpanzee')),
#  (1.088964, ('Llama', 'Gorilla', 'Sloth')),
#  (1.0890244, ('Horse', 'Human', 'Sloth')),
#  (1.0892829, ('Pangolin', 'Llama', 'Sloth')),
#  (1.0893168, ('FlyingLem', 'HowlerMon', 'HairyArma')),
#  (1.0894688, ('Rhino', 'Pangolin', 'Rhesus')),
#  (1.0895462, ('Pangolin', 'HowlerMon', 'Sloth')),
#  (1.0896772, ('Rhino', 'HumpbackW', 'HowlerMon')),
#  (1.0900649, ('Rhino', 'Human', 'Sloth')),
#  (1.0901054, ('HumpbackW', 'Chimpanzee', 'HairyArma')),
#  (1.0902323, ('Llama', 'FlyingLem', 'Human')),
#  (1.0902526, ('Horse', 'Pangolin', 'FlyingLem')),
#  (1.0903147, ('FlyingLem', 'HowlerMon', 'Sloth')),
#  (1.0903256, ('HumpbackW', 'HairyArma', 'Sloth')),
#  (1.0905488, ('HumpbackW', 'Orangutan', 'Sloth')),
#  (1.0907108, ('Rhino', 'Pangolin', 'HairyArma')),
#  (1.0907638, ('Horse', 'Orangutan', 'Sloth')),
#  (1.0908175, ('Horse', 'FlyingLem', 'HairyArma')),
#  (1.0910649, ('Llama', 'HairyArma', 'Sloth')),
#  (1.0911547, ('SpermWhale', 'Human', 'HairyArma')),
#  (1.0911683, ('Horse', 'Llama', 'Human')),
#  (1.0912175, ('Horse', 'HumpbackW', 'FlyingLem')),
#  (1.0912422, ('Horse', 'Rhesus', 'Sloth')),
#  (1.0912595, ('Llama', 'Orangutan', 'HairyArma')),
#  (1.0914501, ('HumpbackW', 'Orangutan', 'HairyArma')),
#  (1.0915442, ('Rhino', 'Orangutan', 'Sloth')),
#  (1.0915793, ('SpermWhale', 'Chimpanzee', 'HairyArma')),
#  (1.0916051, ('FlyingLem', 'Gorilla', 'Sloth')),
#  (1.0917522, ('Horse', 'FlyingLem', 'Sloth')),
#  (1.0918322, ('SpermWhale', 'Orangutan', 'HairyArma')),
#  (1.0920076, ('Rhino', 'Llama', 'Sloth')),
#  (1.0920881, ('Horse', 'Llama', 'Chimpanzee')),
#  (1.0921037, ('HumpbackW', 'Rhesus', 'HairyArma')),
#  (1.0921887, ('Horse', 'Llama', 'HairyArma')),
#  (1.0922337, ('Horse', 'Llama', 'Gorilla')),
#  (1.0922546, ('Llama', 'FlyingLem', 'Orangutan')),
#  (1.0923208, ('Rhino', 'Gorilla', 'Sloth')),
#  (1.092324, ('Pangolin', 'Human', 'HairyArma')),
#  (1.0923362, ('Llama', 'FlyingLem', 'Rhesus')),
#  (1.0925472, ('Horse', 'Llama', 'Orangutan')),
#  (1.0926251, ('Rhino', 'Human', 'HairyArma')),
#  (1.0926282, ('Llama', 'FlyingLem', 'Sloth')),
#  (1.0927459, ('Pangolin', 'Gorilla', 'HairyArma')),
#  (1.0928048, ('Rhino', 'Chimpanzee', 'Sloth')),
#  (1.0929062, ('Horse', 'HairyArma', 'Sloth')),
#  (1.0929997, ('Pangolin', 'Chimpanzee', 'HairyArma')),
#  (1.0930114, ('Horse', 'Rhino', 'Gorilla')),
#  (1.0931019, ('Rhino', 'HumpbackW', 'Rhesus')),
#  (1.0931267, ('Horse', 'FlyingLem', 'Rhesus')),
#  (1.0931964, ('Rhino', 'Pangolin', 'SpermWhale')),
#  (1.0932468, ('SpermWhale', 'FlyingLem', 'Gorilla')),
#  (1.0932488, ('Rhino', 'HowlerMon', 'Sloth')),
#  (1.0933112, ('Pangolin', 'Orangutan', 'HairyArma')),
#  (1.093374, ('Rhino', 'FlyingLem', 'HowlerMon')),
#  (1.0934372, ('Orangutan', 'Gorilla', 'Chimpanzee')),
#  (1.0934454, ('SpermWhale', 'Rhesus', 'HairyArma')),
#  (1.0936577, ('Rhino', 'HumpbackW', 'Human')),
#  (1.0937372, ('Pangolin', 'Llama', 'FlyingLem')),
#  (1.0938334, ('Rhino', 'SpermWhale', 'Gorilla')),
#  (1.0938519, ('SpermWhale', 'FlyingLem', 'Rhesus')),
#  (1.0939624, ('Horse', 'FlyingLem', 'Chimpanzee')),
#  (1.0940661, ('Rhino', 'HumpbackW', 'Chimpanzee')),
#  (1.0941601, ('Horse', 'HumpbackW', 'Sloth')),
#  (1.0942003, ('HumpbackW', 'FlyingLem', 'Gorilla')),
#  (1.0942092, ('Rhino', 'Rhesus', 'Sloth')),
#  (1.0942113, ('Rhino', 'HairyArma', 'Sloth')),
#  (1.0943346, ('Horse', 'Llama', 'FlyingLem')),
#  (1.0943708, ('Horse', 'FlyingLem', 'Orangutan')),
#  (1.0944132, ('HumpbackW', 'FlyingLem', 'Rhesus')),
#  (1.0944333, ('SpermWhale', 'FlyingLem', 'Chimpanzee')),
#  (1.0944753, ('Pangolin', 'HowlerMon', 'HairyArma')),
#  (1.0945337, ('Pangolin', 'HumpbackW', 'HowlerMon')),
#  (1.0945851, ('Rhino', 'Llama', 'FlyingLem')),
#  (1.0946438, ('Rhino', 'HumpbackW', 'Orangutan')),
#  (1.0947127, ('Horse', 'Pangolin', 'Llama')),
#  (1.0947516, ('FlyingLem', 'Human', 'HairyArma')),
#  (1.0948129, ('SpermWhale', 'FlyingLem', 'Orangutan')),
#  (1.0948632, ('Horse', 'FlyingLem', 'Human')),
#  (1.0948993, ('HumpbackW', 'FlyingLem', 'Chimpanzee')),
#  (1.094939, ('Rhino', 'SpermWhale', 'Rhesus')),
#  (1.0950172, ('Pangolin', 'SpermWhale', 'Rhesus')),
#  (1.0950351, ('HumpbackW', 'FlyingLem', 'Orangutan')),
#  (1.0950854, ('Pangolin', 'Gorilla', 'Sloth')),
#  (1.0951442, ('HumpbackW', 'Human', 'Sloth')),
#  (1.0951896, ('Pangolin', 'HumpbackW', 'Rhesus')),
#  (1.0952338, ('Rhino', 'SpermWhale', 'FlyingLem')),
#  (1.0952799, ('HumpbackW', 'Gorilla', 'HairyArma')),
#  (1.0953006, ('HumpbackW', 'FlyingLem', 'Sloth')),
#  (1.095345, ('Rhino', 'Llama', 'HowlerMon')),
#  (1.095478, ('SpermWhale', 'FlyingLem', 'HairyArma')),
#  (1.095498, ('HumpbackW', 'FlyingLem', 'Human')),
#  (1.0955522, ('Horse', 'Pangolin', 'HowlerMon')),
#  (1.0955858, ('Rhino', 'Llama', 'HairyArma')),
#  (1.095676, ('Rhino', 'Pangolin', 'Orangutan')),
#  (1.095686, ('Rhino', 'SpermWhale', 'Human')),
#  (1.0957309, ('Rhino', 'SpermWhale', 'Chimpanzee')),
#  (1.0957491, ('Horse', 'Rhino', 'Orangutan')),
#  (1.0957729, ('HumpbackW', 'Rhesus', 'Sloth')),
#  (1.0958159, ('SpermWhale', 'Gorilla', 'HairyArma')),
#  (1.0958729, ('HumpbackW', 'Chimpanzee', 'Sloth')),
#  (1.095953, ('Rhino', 'HumpbackW', 'Gorilla')),
#  (1.0959554, ('HowlerMon', 'Rhesus', 'Gorilla')),
#  (1.0959569, ('Horse', 'SpermWhale', 'Sloth')),
#  (1.0960014, ('Rhino', 'Pangolin', 'HowlerMon')),
#  (1.0960262, ('Horse', 'Pangolin', 'Human')),
#  (1.0960504, ('FlyingLem', 'Chimpanzee', 'HairyArma')),
#  (1.0960827, ('Llama', 'FlyingLem', 'HairyArma')),
#  (1.0960851, ('Horse', 'Rhino', 'Human')),
#  (1.0961349, ('Rhino', 'Pangolin', 'Gorilla')),
#  (1.0961452, ('Rhino', 'Pangolin', 'Chimpanzee')),
#  (1.0961552, ('Rhino', 'Llama', 'SpermWhale')),
#  (1.0963287, ('Rhino', 'Pangolin', 'Human')),
#  (1.0964204, ('SpermWhale', 'HowlerMon', 'HairyArma')),
#  (1.096425, ('Horse', 'Pangolin', 'Gorilla')),
#  (1.0964524, ('Rhino', 'SpermWhale', 'Sloth')),
#  (1.0965382, ('FlyingLem', 'Orangutan', 'HairyArma')),
#  (1.0965512, ('Rhino', 'HumpbackW', 'FlyingLem')),
#  (1.0965633, ('Horse', 'Rhino', 'Chimpanzee')),
#  (1.096592, ('Horse', 'Pangolin', 'Orangutan')),
#  (1.0966349, ('Horse', 'Chimpanzee', 'HairyArma')),
#  (1.0967149, ('Horse', 'Pangolin', 'Chimpanzee')),
#  (1.0967596, ('SpermWhale', 'FlyingLem', 'Human')),
#  (1.0968549, ('FlyingLem', 'Rhesus', 'HairyArma')),
#  (1.096869, ('Pangolin', 'Llama', 'Human')),
#  (1.0969142, ('Pangolin', 'Llama', 'Gorilla')),
#  (1.0969766, ('Horse', 'Llama', 'Sloth')),
#  (1.0970674, ('Pangolin', 'Llama', 'Chimpanzee')),
#  (1.097156, ('Horse', 'Human', 'HairyArma')),
#  (1.0972061, ('HowlerMon', 'Rhesus', 'Chimpanzee')),
#  (1.0972075, ('Horse', 'Rhino', 'Rhesus')),
#  (1.0972096, ('Rhino', 'SpermWhale', 'Orangutan')),
#  (1.0972927, ('Pangolin', 'HumpbackW', 'Human')),
#  (1.0972956, ('SpermWhale', 'Gorilla', 'Sloth')),
#  (1.0972996, ('HumpbackW', 'FlyingLem', 'HairyArma')),
#  (1.0973059, ('Pangolin', 'SpermWhale', 'Human')),
#  (1.0973186, ('Rhino', 'FlyingLem', 'Orangutan')),
#  (1.0973389, ('Pangolin', 'SpermWhale', 'Gorilla')),
#  (1.0973595, ('Pangolin', 'HumpbackW', 'Gorilla')),
#  (1.0974091, ('Pangolin', 'Human', 'Sloth')),
#  (1.0974269, ('Pangolin', 'Chimpanzee', 'Sloth')),
#  (1.0974401, ('Pangolin', 'Llama', 'Orangutan')),
#  (1.0974473, ('FlyingLem', 'Orangutan', 'Human')),
#  (1.0974752, ('Rhino', 'SpermWhale', 'HairyArma')),
#  (1.0975056, ('HowlerMon', 'Rhesus', 'Orangutan')),
#  (1.0975639, ('Rhino', 'FlyingLem', 'HairyArma')),
#  (1.0976348, ('Rhino', 'FlyingLem', 'Sloth')),
#  (1.0976985, ('Pangolin', 'HumpbackW', 'Chimpanzee')),
#  (1.0977188, ('Pangolin', 'SpermWhale', 'Chimpanzee')),
#  (1.097729, ('Orangutan', 'Human', 'Sloth')),
#  (1.0977505, ('Pangolin', 'SpermWhale', 'Orangutan')),
#  (1.0978979, ('Pangolin', 'HumpbackW', 'Orangutan')),
#  (1.0979275, ('HumpbackW', 'Gorilla', 'Sloth')),
#  (1.0979564, ('HowlerMon', 'Rhesus', 'Human')),
#  (1.0980302, ('Pangolin', 'Orangutan', 'Sloth')),
#  (1.098037, ('Horse', 'Orangutan', 'HairyArma')),
#  (1.0980823, ('Rhino', 'FlyingLem', 'Human')),
#  (1.098105, ('Rhino', 'Pangolin', 'HumpbackW')),
#  (1.0981188, ('SpermWhale', 'Human', 'Sloth')),
#  (1.0981203, ('FlyingLem', 'Gorilla', 'HairyArma')),
#  (1.0982143, ('SpermWhale', 'Orangutan', 'Sloth')),
#  (1.0982144, ('Pangolin', 'Llama', 'HowlerMon')),
#  (1.0982329, ('Llama', 'HowlerMon', 'Sloth')),
#  (1.0982658, ('Pangolin', 'Llama', 'HairyArma')),
#  (1.0982937, ('Rhino', 'FlyingLem', 'Gorilla')),
#  (1.0983014, ('Pangolin', 'Rhesus', 'Sloth')),
#  (1.098398, ('Rhino', 'Pangolin', 'Llama')),
#  (1.0984025, ('Rhino', 'FlyingLem', 'Rhesus')),
#  (1.0984385, ('SpermWhale', 'Rhesus', 'Sloth')),
#  (1.0984597, ('Rhino', 'FlyingLem', 'Chimpanzee')),
#  (1.0985215, ('Rhino', 'HumpbackW', 'Sloth')),
#  (1.0985599, ('Pangolin', 'SpermWhale', 'HowlerMon')),
#  (1.0985955, ('SpermWhale', 'Chimpanzee', 'Sloth'))]

# %%
from sklearn.cluster import KMeans, AffinityPropagation
from sklearn.metrics import davies_bouldin_score
X = [p[6:] for p in params]
fit = AffinityPropagation().fit(X)
davies_bouldin_score(X, fit.labels_)
# Out:
# /home/ben/miniconda3/envs/tensorflow/lib/python3.8/site-packages/sklearn/cluster/_affinity_propagation.py:148: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 1.0 (renaming of 0.25) which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(
# 0.7439558932161066

# %%
sharesies = fit.labels_

# %%
sharesies
# Out:
# array([16,  0, 16, 16, 16, 16, 16, 16, 16, 16,  0, 13, 13,  2,  2,  2,  2,
#        15, 15,  6,  6,  6,  6, 13,  6,  0,  1,  0,  2,  2, 12,  2,  2,  2,
#         4, 12,  9, 12, 15, 12,  2,  2,  2,  2, 13,  2,  2,  2, 15,  6,  2,
#        12,  2, 13,  2,  2, 12, 12, 12, 12,  2,  2, 15, 16, 13, 13, 13, 13,
#         2, 15,  1,  5,  1,  1, 12, 12, 14, 11, 11,  6, 12, 17,  3,  6, 15,
#         8,  6, 15, 12, 15, 13,  2,  2,  2,  2,  6,  2,  2,  2,  2,  2,  2,
#         6,  1, 16,  2,  2,  2,  2,  2,  2,  2,  2,  6,  3, 16,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2, 15,  6,
#         2,  2, 10,  2, 15, 16, 13, 13, 13, 13,  2, 15,  1,  1,  4,  4,  2,
#        15,  2, 11,  4,  2, 15, 17,  3,  2, 15,  8,  2, 15, 10, 15, 13,  0,
#         4,  6, 15,  6,  6,  6,  6,  6,  6, 15,  3,  6,  6,  6,  6,  6,  6,
#         6,  6,  6,  6,  6, 15,  6,  6,  6,  6,  6,  6, 15, 15,  6,  6, 15,
#         6,  6, 12, 12,  5, 16, 16, 16, 15, 15,  5, 16,  5,  5, 15, 15, 14,
#        11,  7, 15, 15, 17,  3, 15, 15,  8, 15, 15, 15, 15, 13,  9,  4,  4,
#         4,  4,  4,  4,  4,  1,  5,  4, 16,  1,  4,  1,  9,  1,  1,  9, 12,
#         6,  6,  6,  6, 12, 15, 12,  5, 13,  5,  5,  5,  6,  6,  5, 12, 12,
#        12,  6,  6, 14, 11,  7,  6,  6,  8,  3, 10,  6,  8, 12,  6,  6,  6,
#        12,  4,  9,  9,  3,  3,  3,  9,  9,  7,  6,  6,  6, 12, 10, 10, 15,
#        15,  5, 13,  5,  5,  5, 15, 15,  5,  1,  4,  4, 12, 15, 14, 11, 11,
#         6,  6, 17,  3,  6, 15,  8,  6,  6,  6,  6, 13, 12, 12, 10,  6, 12,
#         6, 15,  6,  5, 13,  5,  5,  5, 15, 15,  5,  1,  4,  4, 15, 12, 14,
#        11,  7,  6,  6, 17,  3,  6, 15,  8, 15, 15,  6,  6, 13, 16, 13, 13,
#        13, 13, 10,  6,  5,  5,  5,  1, 10, 15, 14, 11, 11,  6, 15, 17,  3,
#        10, 15,  8,  6, 12,  6, 15,  2, 16, 16, 16, 16, 16, 16,  0,  6,  4,
#        13,  5, 17,  3, 13,  1,  6, 13,  1, 13,  1,  4, 14,  6,  2,  1,  5,
#        17,  3,  1,  1,  6,  1,  1,  1, 12, 13, 17, 17, 16, 14,  2,  9, 11,
#         3,  7, 13, 17, 17, 17,  3,  3, 13,  8,  8, 13, 13])

# %%
aln = load_aligned_seqs('brca1.fasta', moltype='dna')
subaln = aln.get_similar(aln.take_seqs(['Human']).seqs[0], min_similarity=0.84)
from cogent3.evolve import distance
from cogent3.phylo import nj
from cogent3.evolve.models import JC69
d = distance.EstimateDistances(subaln[2::3], submodel=HKY85())
d.run(show_progress=False)
mytree = nj.nj(d.get_pairwise_distances())
mytree = mytree.root_at_midpoint()
print(mytree.ascii_art())
type(d)
# Out:
#    0%|                                                                  |00:00<?
#                               /-HairyArma
#                     /edge.1--|
#                    |          \-Sloth
#                    |
#                    |                              /-Llama
#           /edge.7--|                    /edge.3--|
#          |         |                   |         |          /-HumpbackW
#          |         |          /edge.4--|          \edge.2--|
#          |         |         |         |                    \-SpermWhale
#          |         |         |         |
#          |          \edge.6--|          \-Pangolin
# -root----|                   |
#          |                   |          /-Horse
#          |                    \edge.5--|
#          |                              \-Rhino
#          |
#          |          /-FlyingLem
#          |         |
#           \edge.0.2|          /-HowlerMon
#                    |         |
#                     \edge.8--|          /-Rhesus
#                              |         |
#                               \edge.9--|          /-Orangutan
#                                        |         |
#                                         \edge.10-|                    /-Human
#                                                  |          /edge.0--|
#                                                   \edge.11-|          \-Chimpanzee
#                                                            |
#                                                             \-Gorilla
# cogent3.evolve.distance.EstimateDistances

# %%
type(d.get_pairwise_distances())
# Out:
# cogent3.evolve.fast_distance.DistanceMatrix

# %%
from cogent3.evolve.fast_distance import DistanceMatrix

# %%
DistanceMatrix(pd.DataFrame())
# Out:
# =========================
# names         0         1
# -------------------------
#     0    2.0000    3.0000
#     1    4.0000    2.0000
# -------------------------

# %%
nj.nj?

# %%
from cogent3.app import io

# %%
dstore = io.get_data_store("../data/horse_pig_bats-filtered.tinydb")
loader = io.load_db()
dstore.describe
# Out:
# Unlocked db store.
# =====================
# record type    number
# ---------------------
# completed         878
# incomplete        122
# logs                1
# ---------------------
#
# 3 rows x 2 columns

# %%
# %%time
num_alns = len(dstore)
all_triples = []
Q_sharesies = []
t_sharesies = []
for share, aln_name in enumerate(dstore):
#    if share in (150, 217, 475, 619, 627):
#        continue
    aln = loader(aln_name)
    triples = get_triples(aln, codon_position=3, verbose=False)
    all_triples.extend(triples)
    Q_sharesies.extend([share]*len(triples))
    t_sharesies.extend([share]*len(triples))
all_losses, all_parameters = fit_triples(all_triples, steps=4000, verbose=True,
                                         Q_sharesies=Q_sharesies, t_sharesies=t_sharesies)
# Out:
# Fitting 3512 triple(s) using 878 rate matrix(es) and 5268 tip-to-tip distance(s).

# %%
def get_trees(all_triples, all_lengths, all_losses):
    trees = []
    for i in range(0, len(all_losses), 4):
        if np.isnan(all_lengths[i:i+4]).any():
            continue
        tree = pulsar_tree(all_triples[i:i+4], all_lengths[i:i+4], all_losses[i:i+4])
        trees.append(tree)
    return trees

# %%
all_lengths = [np.array([p.numpy() for p in param[4:10]]) for param in all_parameters]

# %%
for i, lengths in enumerate(all_lengths):
    if np.isnan(lengths).any():
        print(i//4)
# Out:
# 17
# 17
# 17
# 17
# 25
# 25
# 25
# 25
# 27
# 27
# 27
# 27
# 94
# 94
# 94
# 94
# 104
# 104
# 104
# 104
# 109
# 109
# 109
# 109
# 113
# 113
# 113
# 113
# 123
# 123
# 123
# 123
# 129
# 129
# 129
# 129
# 165
# 165
# 165
# 165
# 183
# 183
# 183
# 183
# 191
# 191
# 191
# 191
# 205
# 205
# 205
# 205
# 217
# 217
# 217
# 217
# 223
# 223
# 223
# 223
# 232
# 232
# 232
# 232
# 251
# 251
# 251
# 251
# 262
# 262
# 262
# 262
# 271
# 271
# 271
# 271
# 293
# 293
# 293
# 293
# 328
# 328
# 328
# 328
# 329
# 329
# 329
# 329
# 343
# 343
# 343
# 343
# 391
# 391
# 391
# 391
# 404
# 404
# 404
# 404
# 425
# 425
# 425
# 425
# 437
# 437
# 437
# 437
# 460
# 460
# 460
# 460
# 472
# 472
# 472
# 472
# 475
# 475
# 475
# 475
# 478
# 478
# 478
# 478
# 495
# 495
# 495
# 495
# 512
# 512
# 512
# 512
# 517
# 517
# 517
# 517
# 530
# 530
# 530
# 530
# 558
# 558
# 558
# 558
# 560
# 560
# 560
# 560
# 567
# 567
# 567
# 567
# 575
# 575
# 575
# 575
# 588
# 588
# 588
# 588
# 599
# 599
# 599
# 599
# 616
# 616
# 616
# 616
# 619
# 619
# 619
# 619
# 627
# 627
# 627
# 627
# 657
# 657
# 657
# 657
# 669
# 669
# 669
# 669
# 692
# 692
# 692
# 692
# 704
# 704
# 704
# 704
# 717
# 717
# 717
# 717
# 728
# 728
# 728
# 728
# 744
# 744
# 744
# 744
# 762
# 762
# 762
# 762
# 781
# 781
# 781
# 781
# 794
# 794
# 794
# 794
# 851
# 851
# 851
# 851
# 867
# 867
# 867
# 867
# 868
# 868
# 868
# 868
# 871
# 871
# 871
# 871

# %%
trees = get_trees(all_triples, all_lengths, all_losses)

# %%
len(trees)
# Out:
# 820

# %%
ghb_siblings = Counter()
ordered_siblings = []
for tree in trees:
    tree = tree.unrooted()
    for sibling in tree.get_node_matching_name('Greater horseshoe bat').parent.children:
        if sibling.name in ('Microbat', 'Pig', 'Horse'):
            ghb_siblings[sibling.name] += 1
            ordered_siblings.append(sibling.name)

# %%
ghb_siblings
# Out:
# Counter({'Microbat': 527, 'Pig': 147, 'Horse': 146})

# %%
ghb_siblings['Microbat']/len(trees)
# Out:
# 0.6426829268292683
